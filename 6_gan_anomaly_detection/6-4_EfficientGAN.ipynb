# %% [markdown]
# # 6.4 Efficient GANの作成
#
# - 本ファイルでは、Efficient GANのネットワークを実装し、学習をします。

# %% [markdown]
# # 6.4 学習目標
#
# 1.	Efficient GANを実装し、手書き数字画像で異常検知が生成できる

# %% [markdown]
# # 事前準備
# 書籍の指示に従い、本章で使用するデータを用意します

# %%
# パッケージのimport
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# %%
# Setup seeds
torch.manual_seed(1234)
torch.cuda.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %% [markdown]
# # Generatorの実装

# %%
class Generator(nn.Module):

    def __init__(self, z_dim=20):
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Linear(z_dim, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(inplace=True))

        self.layer2 = nn.Sequential(
            nn.Linear(1024, 7*7*128),
            nn.BatchNorm1d(7*7*128),
            nn.ReLU(inplace=True))

        self.layer3 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=128, out_channels=64,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True))

        self.last = nn.Sequential(
            nn.ConvTranspose2d(in_channels=64, out_channels=1,
                               kernel_size=4, stride=2, padding=1),
            nn.Tanh())
        # 注意：白黒画像なので出力チャネルは1つだけ

    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)

        # 転置畳み込み層に入れるためにテンソルの形を整形
        out = out.view(z.shape[0], 128, 7, 7)
        out = self.layer3(out)
        out = self.last(out)

        return out

# %%
# 動作確認
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=20)
G.train()

# 入力する乱数
# バッチノーマライゼーションがあるのでミニバッチ数は2以上
input_z = torch.randn(2, 20)

# 偽画像を出力
fake_images = G(input_z)  # torch.Size([2, 1, 28, 28])
img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()

# %% [markdown]
# # Discriminatorの実装

# %%
class Discriminator(nn.Module):

    def __init__(self, z_dim=20):
        super(Discriminator, self).__init__()

        # 画像側の入力処理
        self.x_layer1 = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))
        # 注意：白黒画像なので入力チャネルは1つだけ

        self.x_layer2 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=4,
                      stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1, inplace=True))

        # 乱数側の入力処理
        self.z_layer1 = nn.Linear(z_dim, 512)

        # 最後の判定
        self.last1 = nn.Sequential(
            nn.Linear(3648, 1024),
            nn.LeakyReLU(0.1, inplace=True))

        self.last2 = nn.Linear(1024, 1)

    def forward(self, x, z):

        # 画像側の入力処理
        x_out = self.x_layer1(x)
        x_out = self.x_layer2(x_out)

        # 乱数側の入力処理
        z = z.view(z.shape[0], -1)
        z_out = self.z_layer1(z)

        # x_outとz_outを結合し、全結合層で判定
        x_out = x_out.view(-1, 64 * 7 * 7)
        out = torch.cat([x_out, z_out], dim=1)
        out = self.last1(out)

        feature = out  # 最後にチャネルを1つに集約する手前の情報
        feature = feature.view(feature.size()[0], -1)  # 2次元に変換

        out = self.last2(out)

        return out, feature

# %%
# 動作確認
D = Discriminator(z_dim=20)

# 偽画像を生成
input_z = torch.randn(2, 20)
fake_images = G(input_z)

# 偽画像をDに入力
d_out, _ = D(fake_images, input_z)

# 出力d_outにSigmoidをかけて0から1に変換
print(nn.Sigmoid()(d_out))
# Out:
# tensor([[0.4322],
#         [0.4629]], grad_fn=<SigmoidBackward0>)

# %% [markdown]
# # Encoderの実装
#
# 画像をzに変換する

# %%
class Encoder(nn.Module):

    def __init__(self, z_dim=20):
        super(Encoder, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3,
                      stride=1),
            nn.LeakyReLU(0.1, inplace=True))
        # 注意：白黒画像なので入力チャネルは1つだけ

        self.layer2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3,
                      stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3,
                      stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.1, inplace=True))

        # ここまでで画像のサイズは7×7になっている
        self.last = nn.Linear(128 * 7 * 7, z_dim)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)

        # FCに入れるためにテンソルの形を整形
        out = out.view(-1, 128 * 7 * 7)
        out = self.last(out)

        return out

# %%
# 動作確認
E = Encoder(z_dim=20)

# 入力する画像データ
x = fake_images  # fake_imagesは上のGで作成したもの

# 画像からzをEncode
z = E(x)

print(z.shape)
print(z)
# Out:
# torch.Size([2, 20])
# tensor([[-0.0669, -0.2844, -0.3601,  0.1404, -0.2922, -0.4834, -0.0025,  0.0258,
#          -0.1298, -0.2613, -0.4292, -0.2584, -0.6141, -0.1440,  0.1142,  0.2175,
#           0.0730,  0.0323, -0.7176, -0.7410],
#         [ 0.4822,  0.3681, -0.0647, -0.0773,  0.0989,  0.3012,  0.8054,  0.4399,
#           1.0848, -0.2809,  0.0619, -0.3179, -0.2963, -0.1191,  0.6562, -0.1707,
#           0.1287, -0.6156,  0.3127, -0.4819]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# # DataLoaderの作成

# %%
def make_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(200):
        img_path = "./data/img_78_28size/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/img_78_28size/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list

# %%
class ImageTransform():
    """画像の前処理クラス"""

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)

# %%
class GAN_Img_Dataset(data.Dataset):
    """画像のDatasetクラス。PyTorchのDatasetクラスを継承"""

    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        '''画像の枚数を返す'''
        return len(self.file_list)

    def __getitem__(self, index):
        '''前処理をした画像のTensor形式のデータを取得'''

        img_path = self.file_list[index]
        img = Image.open(img_path)  # [高さ][幅]白黒

        # 画像の前処理
        img_transformed = self.transform(img)

        return img_transformed

# %%
# DataLoaderの作成と動作確認

# ファイルリストを作成
train_img_list=make_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

# 動作の確認
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す
print(imges.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 28, 28])

# %% [markdown]
# # 学習させる

# %%
# モデルを学習させる関数を作成
use_amp = False
scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
device_amp = 'cuda' if torch.cuda.is_available() else 'cpu'

def train_model(G, D, E, dataloader, num_epochs):

    # GPUが使えるかを確認
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用デバイス：", device)

    # 最適化手法の設定
    lr_ge = 0.0001
    lr_d = 0.0001/4
    beta1, beta2 = 0.5, 0.999
    g_optimizer = torch.optim.Adam(G.parameters(), lr_ge, [beta1, beta2])
    e_optimizer = torch.optim.Adam(E.parameters(), lr_ge, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), lr_d, [beta1, beta2])

    # 誤差関数を定義
    # BCEWithLogitsLossは入力にシグモイド（logit）をかけてから、
    # バイナリークロスエントロピーを計算
    criterion = nn.BCEWithLogitsLoss(reduction='mean')

    # パラメータをハードコーディング
    z_dim = 20
    mini_batch_size = 64

    # ネットワークをGPUへ
    G.to(device)
    E.to(device)
    D.to(device)

    G.train()  # モデルを訓練モードに
    E.train()  # モデルを訓練モードに
    D.train()  # モデルを訓練モードに

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    # 画像の枚数
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    # イテレーションカウンタをセット
    iteration = 1
    logs = []

    # epochのループ
    for epoch in range(num_epochs):

        # 開始時刻を保存
        t_epoch_start = time.time()
        epoch_g_loss = 0.0  # epochの損失和
        epoch_e_loss = 0.0  # epochの損失和
        epoch_d_loss = 0.0  # epochの損失和

        print('-------------')
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-------------')
        print('（train）')

        # データローダーからminibatchずつ取り出すループ
        for imges in dataloader:

            # ミニバッチがサイズが1だと、バッチノーマライゼーションでエラーになるのでさける
            if imges.size()[0] == 1:
                continue

            # ミニバッチサイズの1もしくは0のラベル役のテンソルを作成
            # 正解ラベルと偽ラベルを作成
            # epochの最後のイテレーションはミニバッチの数が少なくなる
            mini_batch_size = imges.size()[0]
            label_real = torch.full((mini_batch_size,), 1).to(device)
            label_fake = torch.full((mini_batch_size,), 0).to(device)

            # GPUが使えるならGPUにデータを送る
            imges = imges.to(device)
            with torch.autocast(device_type=device_amp, dtype=torch.float16, enabled=use_amp):

                # --------------------
                # 1. Discriminatorの学習
                # --------------------
                # 真の画像を判定　
                z_out_real = E(imges)
                d_out_real, _ = D(imges, z_out_real)

                # 偽の画像を生成して判定
                input_z = torch.randn(mini_batch_size, z_dim).to(device)
                fake_images = G(input_z)
                d_out_fake, _ = D(fake_images, input_z)

                # 誤差を計算
                d_loss_real = criterion(d_out_real.view(-1), label_real.float())
                d_loss_fake = criterion(d_out_fake.view(-1), label_fake.float())
                d_loss = d_loss_real + d_loss_fake

                # バックプロパゲーション
                #d_optimizer.zero_grad()
                #d_loss.backward()
                #d_optimizer.step()
                d_optimizer.zero_grad()         
                scaler.scale(d_loss).backward()
                scaler.step(d_optimizer)
                scaler.update()       

                # --------------------
                # 2. Generatorの学習
                # --------------------
                # 偽の画像を生成して判定
                input_z = torch.randn(mini_batch_size, z_dim).to(device)
                fake_images = G(input_z)
                d_out_fake, _ = D(fake_images, input_z)

                # 誤差を計算
                g_loss = criterion(d_out_fake.view(-1), label_real.float())

                # バックプロパゲーション
                g_optimizer.zero_grad()
                #g_loss.backward()
                #g_optimizer.step()
                scaler.scale(g_loss).backward()
                scaler.step(g_optimizer)
                scaler.update()   
                # --------------------
                # 3. Encoderの学習
                # --------------------
                # 真の画像のzを推定
                z_out_real = E(imges)
                d_out_real, _ = D(imges, z_out_real)

                # 誤差を計算
                e_loss = criterion(d_out_real.view(-1), label_fake.float())

                # バックプロパゲーション
                e_optimizer.zero_grad()
                #e_loss.backward()
                #e_optimizer.step()
                scaler.scale(e_loss).backward()
                scaler.step(e_optimizer)
                scaler.update()   
            # --------------------
            # 4. 記録
            # --------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            epoch_e_loss += e_loss.item()
            iteration += 1

        # epochのphaseごとのlossと正解率
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f} ||Epoch_E_Loss:{:.4f}'.format(
            epoch, epoch_d_loss/batch_size, epoch_g_loss/batch_size, epoch_e_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

    print("総イテレーション回数:", iteration)

    return G, D, E

# %%
# ネットワークの初期化
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        # conv2dとConvTranspose2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        # BatchNorm2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('Linear') != -1:
        # 全結合層Linearの初期化
        m.bias.data.fill_(0)


# 初期化の実施
G.apply(weights_init)
E.apply(weights_init)
D.apply(weights_init)

print("ネットワークの初期化完了")
# Out:
# ネットワークの初期化完了

# %%
# 学習・検証を実行する
# 15分ほどかかる
num_epochs = 1500
G_update, D_update, E_update = train_model(
    G, D, E, dataloader=train_dataloader, num_epochs=num_epochs)
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 0/1500
# -------------
# （train）
# -------------
# epoch 0 || Epoch_D_Loss:0.2098 ||Epoch_G_Loss:0.1230 ||Epoch_E_Loss:0.0367
# timer:  2.3217 sec.
# -------------
# Epoch 1/1500
# -------------
# （train）
# -------------
# epoch 1 || Epoch_D_Loss:0.1479 ||Epoch_G_Loss:0.1216 ||Epoch_E_Loss:0.0710
# timer:  1.9358 sec.
# -------------
# Epoch 2/1500
# -------------
# （train）
# -------------
# epoch 2 || Epoch_D_Loss:0.1042 ||Epoch_G_Loss:0.1148 ||Epoch_E_Loss:0.1255
# timer:  2.1028 sec.
# -------------
# Epoch 3/1500
# -------------
# （train）
# -------------
# epoch 3 || Epoch_D_Loss:0.0819 ||Epoch_G_Loss:0.1074 ||Epoch_E_Loss:0.1907
# timer:  2.6141 sec.
# -------------
# Epoch 4/1500
# -------------
# （train）
# -------------
# epoch 4 || Epoch_D_Loss:0.0782 ||Epoch_G_Loss:0.0998 ||Epoch_E_Loss:0.2315
# timer:  1.9816 sec.
# -------------
# Epoch 5/1500
# -------------
# （train）
# -------------
# epoch 5 || Epoch_D_Loss:0.0831 ||Epoch_G_Loss:0.0911 ||Epoch_E_Loss:0.2526
# timer:  2.0313 sec.
# -------------
# Epoch 6/1500
# -------------
# （train）
# -------------
# epoch 6 || Epoch_D_Loss:0.0852 ||Epoch_G_Loss:0.0869 ||Epoch_E_Loss:0.2650
# timer:  2.3631 sec.
# -------------
# Epoch 7/1500
# -------------
# （train）
# -------------
# epoch 7 || Epoch_D_Loss:0.0814 ||Epoch_G_Loss:0.0869 ||Epoch_E_Loss:0.2705
# timer:  2.1578 sec.
# -------------
# Epoch 8/1500
# -------------
# （train）
# -------------
# epoch 8 || Epoch_D_Loss:0.0768 ||Epoch_G_Loss:0.0931 ||Epoch_E_Loss:0.2740
# timer:  2.0532 sec.
# -------------
# Epoch 9/1500
# -------------
# （train）
# -------------
# epoch 9 || Epoch_D_Loss:0.0710 ||Epoch_G_Loss:0.1029 ||Epoch_E_Loss:0.2816
# timer:  2.5087 sec.
# -------------
# Epoch 10/1500
# -------------
# （train）
# -------------
# epoch 10 || Epoch_D_Loss:0.0665 ||Epoch_G_Loss:0.1099 ||Epoch_E_Loss:0.2847
# timer:  2.2954 sec.
# -------------
# Epoch 11/1500
# -------------
# （train）
# -------------
# epoch 11 || Epoch_D_Loss:0.0613 ||Epoch_G_Loss:0.1149 ||Epoch_E_Loss:0.2893
# timer:  1.9608 sec.
# -------------
# Epoch 12/1500
# -------------
# （train）
# -------------
# epoch 12 || Epoch_D_Loss:0.0598 ||Epoch_G_Loss:0.1183 ||Epoch_E_Loss:0.2767
# timer:  2.5480 sec.
# -------------
# Epoch 13/1500
# -------------
# （train）
# -------------
# epoch 13 || Epoch_D_Loss:0.0628 ||Epoch_G_Loss:0.1240 ||Epoch_E_Loss:0.2605
# timer:  2.0863 sec.
# -------------
# Epoch 14/1500
# -------------
# （train）
# -------------
# epoch 14 || Epoch_D_Loss:0.0574 ||Epoch_G_Loss:0.1274 ||Epoch_E_Loss:0.2726
# timer:  2.0103 sec.
# -------------
# Epoch 15/1500
# -------------
# （train）
# -------------
# epoch 15 || Epoch_D_Loss:0.0520 ||Epoch_G_Loss:0.1333 ||Epoch_E_Loss:0.3039
# timer:  2.4836 sec.
# -------------
# Epoch 16/1500
# -------------
# （train）
# -------------
# epoch 16 || Epoch_D_Loss:0.0476 ||Epoch_G_Loss:0.1369 ||Epoch_E_Loss:0.3235
# timer:  2.5295 sec.
# -------------
# Epoch 17/1500
# -------------
# （train）
# -------------
# epoch 17 || Epoch_D_Loss:0.0453 ||Epoch_G_Loss:0.1415 ||Epoch_E_Loss:0.3300
# timer:  1.9777 sec.
# -------------
# Epoch 18/1500
# -------------
# （train）
# -------------
# epoch 18 || Epoch_D_Loss:0.0446 ||Epoch_G_Loss:0.1519 ||Epoch_E_Loss:0.3286
# timer:  2.0814 sec.
# -------------
# Epoch 19/1500
# -------------
# （train）
# -------------
# epoch 19 || Epoch_D_Loss:0.0441 ||Epoch_G_Loss:0.1554 ||Epoch_E_Loss:0.2967
# timer:  2.3957 sec.
# -------------
# Epoch 20/1500
# -------------
# （train）
# -------------
# epoch 20 || Epoch_D_Loss:0.0430 ||Epoch_G_Loss:0.1602 ||Epoch_E_Loss:0.2929
# timer:  2.4367 sec.
# -------------
# Epoch 21/1500
# -------------
# （train）
# -------------
# epoch 21 || Epoch_D_Loss:0.0390 ||Epoch_G_Loss:0.1643 ||Epoch_E_Loss:0.3096
# timer:  1.9371 sec.
# -------------
# Epoch 22/1500
# -------------
# （train）
# -------------
# epoch 22 || Epoch_D_Loss:0.0374 ||Epoch_G_Loss:0.1725 ||Epoch_E_Loss:0.3279
# timer:  2.3163 sec.
# -------------
# Epoch 23/1500
# -------------
# （train）
# -------------
# epoch 23 || Epoch_D_Loss:0.0335 ||Epoch_G_Loss:0.1828 ||Epoch_E_Loss:0.3344
# timer:  2.1749 sec.
# -------------
# Epoch 24/1500
# -------------
# （train）
# -------------
# epoch 24 || Epoch_D_Loss:0.0306 ||Epoch_G_Loss:0.1918 ||Epoch_E_Loss:0.3381
# timer:  1.9210 sec.
# -------------
# Epoch 25/1500
# -------------
# （train）
# -------------
# epoch 25 || Epoch_D_Loss:0.0282 ||Epoch_G_Loss:0.2101 ||Epoch_E_Loss:0.3207
# timer:  2.1919 sec.
# -------------
# Epoch 26/1500
# -------------
# （train）
# -------------
# epoch 26 || Epoch_D_Loss:0.0351 ||Epoch_G_Loss:0.2115 ||Epoch_E_Loss:0.2724
# timer:  2.4854 sec.
# -------------
# Epoch 27/1500
# -------------
# （train）
# -------------
# epoch 27 || Epoch_D_Loss:0.0315 ||Epoch_G_Loss:0.2088 ||Epoch_E_Loss:0.3009
# timer:  1.9259 sec.
# -------------
# Epoch 28/1500
# -------------
# （train）
# -------------
# epoch 28 || Epoch_D_Loss:0.0265 ||Epoch_G_Loss:0.2271 ||Epoch_E_Loss:0.3211
# timer:  1.9913 sec.
# -------------
# Epoch 29/1500
# -------------
# （train）
# -------------
# epoch 29 || Epoch_D_Loss:0.0232 ||Epoch_G_Loss:0.2457 ||Epoch_E_Loss:0.3313
# timer:  2.3060 sec.
# -------------
# Epoch 30/1500
# -------------
# （train）
# -------------
# epoch 30 || Epoch_D_Loss:0.0225 ||Epoch_G_Loss:0.2574 ||Epoch_E_Loss:0.3203
# timer:  2.1869 sec.
# -------------
# Epoch 31/1500
# -------------
# （train）
# -------------
# epoch 31 || Epoch_D_Loss:0.0252 ||Epoch_G_Loss:0.2581 ||Epoch_E_Loss:0.3116
# timer:  2.0030 sec.
# -------------
# Epoch 32/1500
# -------------
# （train）
# -------------
# epoch 32 || Epoch_D_Loss:0.0258 ||Epoch_G_Loss:0.2497 ||Epoch_E_Loss:0.3112
# timer:  2.2687 sec.
# -------------
# Epoch 33/1500
# -------------
# （train）
# -------------
# epoch 33 || Epoch_D_Loss:0.0268 ||Epoch_G_Loss:0.2628 ||Epoch_E_Loss:0.2995
# timer:  2.1971 sec.
# -------------
# Epoch 34/1500
# -------------
# （train）
# -------------
# epoch 34 || Epoch_D_Loss:0.0241 ||Epoch_G_Loss:0.2673 ||Epoch_E_Loss:0.3112
# timer:  1.9815 sec.
# -------------
# Epoch 35/1500
# -------------
# （train）
# -------------
# epoch 35 || Epoch_D_Loss:0.0184 ||Epoch_G_Loss:0.2826 ||Epoch_E_Loss:0.3421
# timer:  2.0547 sec.
# -------------
# Epoch 36/1500
# -------------
# （train）
# -------------
# epoch 36 || Epoch_D_Loss:0.0157 ||Epoch_G_Loss:0.2981 ||Epoch_E_Loss:0.3576
# timer:  2.5779 sec.
# -------------
# Epoch 37/1500
# -------------
# （train）
# -------------
# epoch 37 || Epoch_D_Loss:0.0155 ||Epoch_G_Loss:0.3098 ||Epoch_E_Loss:0.3590
# timer:  2.2073 sec.
# -------------
# Epoch 38/1500
# -------------
# （train）
# -------------
# epoch 38 || Epoch_D_Loss:0.0147 ||Epoch_G_Loss:0.3044 ||Epoch_E_Loss:0.3624
# timer:  2.2640 sec.
# -------------
# Epoch 39/1500
# -------------
# （train）
# -------------
# epoch 39 || Epoch_D_Loss:0.0172 ||Epoch_G_Loss:0.2977 ||Epoch_E_Loss:0.3475
# timer:  2.1920 sec.
# -------------
# Epoch 40/1500
# -------------
# （train）
# -------------
# epoch 40 || Epoch_D_Loss:0.0192 ||Epoch_G_Loss:0.2892 ||Epoch_E_Loss:0.3389
# timer:  1.9986 sec.
# -------------
# Epoch 41/1500
# -------------
# （train）
# -------------
# epoch 41 || Epoch_D_Loss:0.0177 ||Epoch_G_Loss:0.2915 ||Epoch_E_Loss:0.3544
# timer:  2.2228 sec.
# -------------
# Epoch 42/1500
# -------------
# （train）
# -------------
# epoch 42 || Epoch_D_Loss:0.0124 ||Epoch_G_Loss:0.3272 ||Epoch_E_Loss:0.3850
# timer:  1.9115 sec.
# -------------
# Epoch 43/1500
# -------------
# （train）
# -------------
# epoch 43 || Epoch_D_Loss:0.0118 ||Epoch_G_Loss:0.3377 ||Epoch_E_Loss:0.3904
# timer:  2.0114 sec.
# -------------
# Epoch 44/1500
# -------------
# （train）
# -------------
# epoch 44 || Epoch_D_Loss:0.0133 ||Epoch_G_Loss:0.3350 ||Epoch_E_Loss:0.3731
# timer:  2.3347 sec.
# -------------
# Epoch 45/1500
# -------------
# （train）
# -------------
# epoch 45 || Epoch_D_Loss:0.0164 ||Epoch_G_Loss:0.3038 ||Epoch_E_Loss:0.3500
# timer:  2.1631 sec.
# -------------
# Epoch 46/1500
# -------------
# （train）
# -------------
# epoch 46 || Epoch_D_Loss:0.0186 ||Epoch_G_Loss:0.2943 ||Epoch_E_Loss:0.3405
# timer:  1.8637 sec.
# -------------
# Epoch 47/1500
# -------------
# （train）
# -------------
# epoch 47 || Epoch_D_Loss:0.0190 ||Epoch_G_Loss:0.2903 ||Epoch_E_Loss:0.3417
# timer:  2.1400 sec.
# -------------
# Epoch 48/1500
# -------------
# （train）
# -------------
# epoch 48 || Epoch_D_Loss:0.0169 ||Epoch_G_Loss:0.3091 ||Epoch_E_Loss:0.3445
# timer:  2.5216 sec.
# -------------
# Epoch 49/1500
# -------------
# （train）
# -------------
# epoch 49 || Epoch_D_Loss:0.0132 ||Epoch_G_Loss:0.3331 ||Epoch_E_Loss:0.3680
# timer:  2.2809 sec.
# -------------
# Epoch 50/1500
# -------------
# （train）
# -------------
# epoch 50 || Epoch_D_Loss:0.0113 ||Epoch_G_Loss:0.3620 ||Epoch_E_Loss:0.3832
# timer:  2.2026 sec.
# -------------
# Epoch 51/1500
# -------------
# （train）
# -------------
# epoch 51 || Epoch_D_Loss:0.0093 ||Epoch_G_Loss:0.3681 ||Epoch_E_Loss:0.3991
# timer:  2.3713 sec.
# -------------
# Epoch 52/1500
# -------------
# （train）
# -------------
# epoch 52 || Epoch_D_Loss:0.0085 ||Epoch_G_Loss:0.3750 ||Epoch_E_Loss:0.4117
# timer:  1.9802 sec.
# -------------
# Epoch 53/1500
# -------------
# （train）
# -------------
# epoch 53 || Epoch_D_Loss:0.0078 ||Epoch_G_Loss:0.3868 ||Epoch_E_Loss:0.4185
# timer:  2.3612 sec.
# -------------
# Epoch 54/1500
# -------------
# （train）
# -------------
# epoch 54 || Epoch_D_Loss:0.0086 ||Epoch_G_Loss:0.3837 ||Epoch_E_Loss:0.4091
# timer:  2.3314 sec.
# -------------
# Epoch 55/1500
# -------------
# （train）
# -------------
# epoch 55 || Epoch_D_Loss:0.0091 ||Epoch_G_Loss:0.3870 ||Epoch_E_Loss:0.4010
# timer:  2.1011 sec.
# -------------
# Epoch 56/1500
# -------------
# （train）
# -------------
# epoch 56 || Epoch_D_Loss:0.0108 ||Epoch_G_Loss:0.3656 ||Epoch_E_Loss:0.3835
# timer:  2.0448 sec.
# -------------
# Epoch 57/1500
# -------------
# （train）
# -------------
# epoch 57 || Epoch_D_Loss:0.0139 ||Epoch_G_Loss:0.3482 ||Epoch_E_Loss:0.3632
# timer:  2.4660 sec.
# -------------
# Epoch 58/1500
# -------------
# （train）
# -------------
# epoch 58 || Epoch_D_Loss:0.0123 ||Epoch_G_Loss:0.3598 ||Epoch_E_Loss:0.3762
# timer:  2.3769 sec.
# -------------
# Epoch 59/1500
# -------------
# （train）
# -------------
# epoch 59 || Epoch_D_Loss:0.0135 ||Epoch_G_Loss:0.3586 ||Epoch_E_Loss:0.3658
# timer:  1.8811 sec.
# -------------
# Epoch 60/1500
# -------------
# （train）
# -------------
# epoch 60 || Epoch_D_Loss:0.0146 ||Epoch_G_Loss:0.3497 ||Epoch_E_Loss:0.3629
# timer:  2.0370 sec.
# -------------
# Epoch 61/1500
# -------------
# （train）
# -------------
# epoch 61 || Epoch_D_Loss:0.0162 ||Epoch_G_Loss:0.3433 ||Epoch_E_Loss:0.3522
# timer:  2.4379 sec.
# -------------
# Epoch 62/1500
# -------------
# （train）
# -------------
# epoch 62 || Epoch_D_Loss:0.0160 ||Epoch_G_Loss:0.3627 ||Epoch_E_Loss:0.3539
# timer:  2.1823 sec.
# -------------
# Epoch 63/1500
# -------------
# （train）
# -------------
# epoch 63 || Epoch_D_Loss:0.0136 ||Epoch_G_Loss:0.3574 ||Epoch_E_Loss:0.3629
# timer:  2.0691 sec.
# -------------
# Epoch 64/1500
# -------------
# （train）
# -------------
# epoch 64 || Epoch_D_Loss:0.0152 ||Epoch_G_Loss:0.3524 ||Epoch_E_Loss:0.3604
# timer:  2.3236 sec.
# -------------
# Epoch 65/1500
# -------------
# （train）
# -------------
# epoch 65 || Epoch_D_Loss:0.0158 ||Epoch_G_Loss:0.3460 ||Epoch_E_Loss:0.3594
# timer:  2.3598 sec.
# -------------
# Epoch 66/1500
# -------------
# （train）
# -------------
# epoch 66 || Epoch_D_Loss:0.0154 ||Epoch_G_Loss:0.3600 ||Epoch_E_Loss:0.3570
# timer:  2.0050 sec.
# -------------
# Epoch 67/1500
# -------------
# （train）
# -------------
# epoch 67 || Epoch_D_Loss:0.0138 ||Epoch_G_Loss:0.3744 ||Epoch_E_Loss:0.3649
# timer:  2.0748 sec.
# -------------
# Epoch 68/1500
# -------------
# （train）
# -------------
# epoch 68 || Epoch_D_Loss:0.0127 ||Epoch_G_Loss:0.3696 ||Epoch_E_Loss:0.3758
# timer:  2.5398 sec.
# -------------
# Epoch 69/1500
# -------------
# （train）
# -------------
# epoch 69 || Epoch_D_Loss:0.0110 ||Epoch_G_Loss:0.3883 ||Epoch_E_Loss:0.3904
# timer:  2.0481 sec.
# -------------
# Epoch 70/1500
# -------------
# （train）
# -------------
# epoch 70 || Epoch_D_Loss:0.0097 ||Epoch_G_Loss:0.4120 ||Epoch_E_Loss:0.4096
# timer:  2.0780 sec.
# -------------
# Epoch 71/1500
# -------------
# （train）
# -------------
# epoch 71 || Epoch_D_Loss:0.0096 ||Epoch_G_Loss:0.3925 ||Epoch_E_Loss:0.4071
# timer:  2.2955 sec.
# -------------
# Epoch 72/1500
# -------------
# （train）
# -------------
# epoch 72 || Epoch_D_Loss:0.0128 ||Epoch_G_Loss:0.3694 ||Epoch_E_Loss:0.3943
# timer:  2.4352 sec.
# -------------
# Epoch 73/1500
# -------------
# （train）
# -------------
# epoch 73 || Epoch_D_Loss:0.0235 ||Epoch_G_Loss:0.3215 ||Epoch_E_Loss:0.3790
# timer:  2.0725 sec.
# -------------
# Epoch 74/1500
# -------------
# （train）
# -------------
# epoch 74 || Epoch_D_Loss:0.0223 ||Epoch_G_Loss:0.3433 ||Epoch_E_Loss:0.3568
# timer:  2.0766 sec.
# -------------
# Epoch 75/1500
# -------------
# （train）
# -------------
# epoch 75 || Epoch_D_Loss:0.0180 ||Epoch_G_Loss:0.3448 ||Epoch_E_Loss:0.3538
# timer:  2.6196 sec.
# -------------
# Epoch 76/1500
# -------------
# （train）
# -------------
# epoch 76 || Epoch_D_Loss:0.0125 ||Epoch_G_Loss:0.3570 ||Epoch_E_Loss:0.3810
# timer:  2.0756 sec.
# -------------
# Epoch 77/1500
# -------------
# （train）
# -------------
# epoch 77 || Epoch_D_Loss:0.0096 ||Epoch_G_Loss:0.3780 ||Epoch_E_Loss:0.3918
# timer:  2.1120 sec.
# -------------
# Epoch 78/1500
# -------------
# （train）
# -------------
# epoch 78 || Epoch_D_Loss:0.0094 ||Epoch_G_Loss:0.3884 ||Epoch_E_Loss:0.3957
# timer:  2.2603 sec.
# -------------
# Epoch 79/1500
# -------------
# （train）
# -------------
# epoch 79 || Epoch_D_Loss:0.0097 ||Epoch_G_Loss:0.3726 ||Epoch_E_Loss:0.3914
# timer:  2.3913 sec.
# -------------
# Epoch 80/1500
# -------------
# （train）
# -------------
# epoch 80 || Epoch_D_Loss:0.0133 ||Epoch_G_Loss:0.3437 ||Epoch_E_Loss:0.3702
# timer:  1.8878 sec.
# -------------
# Epoch 81/1500
# -------------
# （train）
# -------------
# epoch 81 || Epoch_D_Loss:0.0129 ||Epoch_G_Loss:0.3652 ||Epoch_E_Loss:0.3742
# timer:  2.1950 sec.
# -------------
# Epoch 82/1500
# -------------
# （train）
# -------------
# epoch 82 || Epoch_D_Loss:0.0111 ||Epoch_G_Loss:0.3712 ||Epoch_E_Loss:0.3960
# timer:  2.6405 sec.
# -------------
# Epoch 83/1500
# -------------
# （train）
# -------------
# epoch 83 || Epoch_D_Loss:0.0102 ||Epoch_G_Loss:0.3804 ||Epoch_E_Loss:0.3997
# timer:  1.9500 sec.
# -------------
# Epoch 84/1500
# -------------
# （train）
# -------------
# epoch 84 || Epoch_D_Loss:0.0117 ||Epoch_G_Loss:0.3547 ||Epoch_E_Loss:0.4017
# timer:  1.9725 sec.
# -------------
# Epoch 85/1500
# -------------
# （train）
# -------------
# epoch 85 || Epoch_D_Loss:0.0143 ||Epoch_G_Loss:0.3499 ||Epoch_E_Loss:0.3772
# timer:  2.3582 sec.
# -------------
# Epoch 86/1500
# -------------
# （train）
# -------------
# epoch 86 || Epoch_D_Loss:0.0181 ||Epoch_G_Loss:0.3243 ||Epoch_E_Loss:0.3702
# timer:  2.7096 sec.
# -------------
# Epoch 87/1500
# -------------
# （train）
# -------------
# epoch 87 || Epoch_D_Loss:0.0129 ||Epoch_G_Loss:0.3821 ||Epoch_E_Loss:0.3792
# timer:  1.9052 sec.
# -------------
# Epoch 88/1500
# -------------
# （train）
# -------------
# epoch 88 || Epoch_D_Loss:0.0102 ||Epoch_G_Loss:0.3988 ||Epoch_E_Loss:0.4091
# timer:  2.0005 sec.
# -------------
# Epoch 89/1500
# -------------
# （train）
# -------------
# epoch 89 || Epoch_D_Loss:0.0097 ||Epoch_G_Loss:0.3888 ||Epoch_E_Loss:0.4138
# timer:  2.3712 sec.
# -------------
# Epoch 90/1500
# -------------
# （train）
# -------------
# epoch 90 || Epoch_D_Loss:0.0124 ||Epoch_G_Loss:0.3721 ||Epoch_E_Loss:0.3866
# timer:  2.3810 sec.
# -------------
# Epoch 91/1500
# -------------
# （train）
# -------------
# epoch 91 || Epoch_D_Loss:0.0311 ||Epoch_G_Loss:0.3680 ||Epoch_E_Loss:0.4421
# timer:  2.1116 sec.
# -------------
# Epoch 92/1500
# -------------
# （train）
# -------------
# epoch 92 || Epoch_D_Loss:0.0136 ||Epoch_G_Loss:0.3708 ||Epoch_E_Loss:0.3750
# timer:  2.4920 sec.
# -------------
# Epoch 93/1500
# -------------
# （train）
# -------------
# epoch 93 || Epoch_D_Loss:0.0183 ||Epoch_G_Loss:0.3626 ||Epoch_E_Loss:0.3550
# timer:  2.0914 sec.
# -------------
# Epoch 94/1500
# -------------
# （train）
# -------------
# epoch 94 || Epoch_D_Loss:0.0150 ||Epoch_G_Loss:0.3698 ||Epoch_E_Loss:0.3707
# timer:  1.9751 sec.
# -------------
# Epoch 95/1500
# -------------
# （train）
# -------------
# epoch 95 || Epoch_D_Loss:0.0138 ||Epoch_G_Loss:0.3748 ||Epoch_E_Loss:0.4071
# timer:  2.2403 sec.
# -------------
# Epoch 96/1500
# -------------
# （train）
# -------------
# epoch 96 || Epoch_D_Loss:0.0130 ||Epoch_G_Loss:0.3796 ||Epoch_E_Loss:0.4104
# timer:  2.4896 sec.
# -------------
# Epoch 97/1500
# -------------
# （train）
# -------------
# epoch 97 || Epoch_D_Loss:0.0145 ||Epoch_G_Loss:0.3819 ||Epoch_E_Loss:0.3929
# timer:  1.8594 sec.
# -------------
# Epoch 98/1500
# -------------
# （train）
# -------------
# epoch 98 || Epoch_D_Loss:0.0211 ||Epoch_G_Loss:0.3525 ||Epoch_E_Loss:0.3682
# timer:  2.1816 sec.
# -------------
# Epoch 99/1500
# -------------
# （train）
# -------------
# epoch 99 || Epoch_D_Loss:0.0423 ||Epoch_G_Loss:0.3156 ||Epoch_E_Loss:0.4019
# timer:  2.2929 sec.
# -------------
# Epoch 100/1500
# -------------
# （train）
# -------------
# epoch 100 || Epoch_D_Loss:0.0413 ||Epoch_G_Loss:0.4999 ||Epoch_E_Loss:0.4583
# timer:  1.9173 sec.
# -------------
# Epoch 101/1500
# -------------
# （train）
# -------------
# epoch 101 || Epoch_D_Loss:0.0199 ||Epoch_G_Loss:0.3332 ||Epoch_E_Loss:0.3725
# timer:  2.3558 sec.
# -------------
# Epoch 102/1500
# -------------
# （train）
# -------------
# epoch 102 || Epoch_D_Loss:0.0274 ||Epoch_G_Loss:0.3236 ||Epoch_E_Loss:0.3411
# timer:  2.1277 sec.
# -------------
# Epoch 103/1500
# -------------
# （train）
# -------------
# epoch 103 || Epoch_D_Loss:0.0276 ||Epoch_G_Loss:0.3266 ||Epoch_E_Loss:0.3595
# timer:  1.9241 sec.
# -------------
# Epoch 104/1500
# -------------
# （train）
# -------------
# epoch 104 || Epoch_D_Loss:0.0271 ||Epoch_G_Loss:0.3204 ||Epoch_E_Loss:0.3552
# timer:  2.0620 sec.
# -------------
# Epoch 105/1500
# -------------
# （train）
# -------------
# epoch 105 || Epoch_D_Loss:0.0371 ||Epoch_G_Loss:0.3144 ||Epoch_E_Loss:0.3213
# timer:  2.5578 sec.
# -------------
# Epoch 106/1500
# -------------
# （train）
# -------------
# epoch 106 || Epoch_D_Loss:0.0370 ||Epoch_G_Loss:0.3213 ||Epoch_E_Loss:0.3645
# timer:  2.3344 sec.
# -------------
# Epoch 107/1500
# -------------
# （train）
# -------------
# epoch 107 || Epoch_D_Loss:0.0350 ||Epoch_G_Loss:0.2842 ||Epoch_E_Loss:0.3265
# timer:  2.1820 sec.
# -------------
# Epoch 108/1500
# -------------
# （train）
# -------------
# epoch 108 || Epoch_D_Loss:0.0335 ||Epoch_G_Loss:0.3283 ||Epoch_E_Loss:0.3539
# timer:  2.3324 sec.
# -------------
# Epoch 109/1500
# -------------
# （train）
# -------------
# epoch 109 || Epoch_D_Loss:0.0200 ||Epoch_G_Loss:0.3206 ||Epoch_E_Loss:0.3644
# timer:  1.9878 sec.
# -------------
# Epoch 110/1500
# -------------
# （train）
# -------------
# epoch 110 || Epoch_D_Loss:0.0166 ||Epoch_G_Loss:0.3662 ||Epoch_E_Loss:0.3803
# timer:  2.4047 sec.
# -------------
# Epoch 111/1500
# -------------
# （train）
# -------------
# epoch 111 || Epoch_D_Loss:0.0178 ||Epoch_G_Loss:0.3472 ||Epoch_E_Loss:0.3814
# timer:  2.2416 sec.
# -------------
# Epoch 112/1500
# -------------
# （train）
# -------------
# epoch 112 || Epoch_D_Loss:0.0260 ||Epoch_G_Loss:0.3072 ||Epoch_E_Loss:0.3496
# timer:  2.0043 sec.
# -------------
# Epoch 113/1500
# -------------
# （train）
# -------------
# epoch 113 || Epoch_D_Loss:0.0346 ||Epoch_G_Loss:0.2924 ||Epoch_E_Loss:0.3267
# timer:  2.4546 sec.
# -------------
# Epoch 114/1500
# -------------
# （train）
# -------------
# epoch 114 || Epoch_D_Loss:0.0339 ||Epoch_G_Loss:0.3329 ||Epoch_E_Loss:0.3313
# timer:  1.8806 sec.
# -------------
# Epoch 115/1500
# -------------
# （train）
# -------------
# epoch 115 || Epoch_D_Loss:0.0223 ||Epoch_G_Loss:0.3315 ||Epoch_E_Loss:0.3568
# timer:  1.9747 sec.
# -------------
# Epoch 116/1500
# -------------
# （train）
# -------------
# epoch 116 || Epoch_D_Loss:0.0211 ||Epoch_G_Loss:0.3371 ||Epoch_E_Loss:0.3546
# timer:  2.3281 sec.
# -------------
# Epoch 117/1500
# -------------
# （train）
# -------------
# epoch 117 || Epoch_D_Loss:0.0227 ||Epoch_G_Loss:0.3170 ||Epoch_E_Loss:0.3493
# timer:  2.5959 sec.
# -------------
# Epoch 118/1500
# -------------
# （train）
# -------------
# epoch 118 || Epoch_D_Loss:0.0377 ||Epoch_G_Loss:0.2770 ||Epoch_E_Loss:0.3285
# timer:  1.7524 sec.
# -------------
# Epoch 119/1500
# -------------
# （train）
# -------------
# epoch 119 || Epoch_D_Loss:0.0540 ||Epoch_G_Loss:0.3409 ||Epoch_E_Loss:0.3332
# timer:  2.0574 sec.
# -------------
# Epoch 120/1500
# -------------
# （train）
# -------------
# epoch 120 || Epoch_D_Loss:0.0371 ||Epoch_G_Loss:0.2761 ||Epoch_E_Loss:0.3074
# timer:  2.3156 sec.
# -------------
# Epoch 121/1500
# -------------
# （train）
# -------------
# epoch 121 || Epoch_D_Loss:0.0296 ||Epoch_G_Loss:0.2960 ||Epoch_E_Loss:0.3110
# timer:  2.2927 sec.
# -------------
# Epoch 122/1500
# -------------
# （train）
# -------------
# epoch 122 || Epoch_D_Loss:0.0250 ||Epoch_G_Loss:0.2861 ||Epoch_E_Loss:0.3421
# timer:  1.9585 sec.
# -------------
# Epoch 123/1500
# -------------
# （train）
# -------------
# epoch 123 || Epoch_D_Loss:0.0275 ||Epoch_G_Loss:0.3164 ||Epoch_E_Loss:0.3172
# timer:  2.0465 sec.
# -------------
# Epoch 124/1500
# -------------
# （train）
# -------------
# epoch 124 || Epoch_D_Loss:0.0262 ||Epoch_G_Loss:0.3019 ||Epoch_E_Loss:0.3408
# timer:  2.4348 sec.
# -------------
# Epoch 125/1500
# -------------
# （train）
# -------------
# epoch 125 || Epoch_D_Loss:0.0281 ||Epoch_G_Loss:0.3026 ||Epoch_E_Loss:0.3302
# timer:  2.2625 sec.
# -------------
# Epoch 126/1500
# -------------
# （train）
# -------------
# epoch 126 || Epoch_D_Loss:0.0360 ||Epoch_G_Loss:0.2728 ||Epoch_E_Loss:0.2976
# timer:  1.8586 sec.
# -------------
# Epoch 127/1500
# -------------
# （train）
# -------------
# epoch 127 || Epoch_D_Loss:0.0618 ||Epoch_G_Loss:0.2368 ||Epoch_E_Loss:0.3231
# timer:  2.0707 sec.
# -------------
# Epoch 128/1500
# -------------
# （train）
# -------------
# epoch 128 || Epoch_D_Loss:0.0493 ||Epoch_G_Loss:0.2452 ||Epoch_E_Loss:0.2982
# timer:  2.7094 sec.
# -------------
# Epoch 129/1500
# -------------
# （train）
# -------------
# epoch 129 || Epoch_D_Loss:0.0395 ||Epoch_G_Loss:0.2713 ||Epoch_E_Loss:0.3070
# timer:  2.1268 sec.
# -------------
# Epoch 130/1500
# -------------
# （train）
# -------------
# epoch 130 || Epoch_D_Loss:0.0443 ||Epoch_G_Loss:0.2870 ||Epoch_E_Loss:0.2892
# timer:  2.2646 sec.
# -------------
# Epoch 131/1500
# -------------
# （train）
# -------------
# epoch 131 || Epoch_D_Loss:0.0432 ||Epoch_G_Loss:0.2808 ||Epoch_E_Loss:0.2853
# timer:  2.1426 sec.
# -------------
# Epoch 132/1500
# -------------
# （train）
# -------------
# epoch 132 || Epoch_D_Loss:0.0399 ||Epoch_G_Loss:0.2699 ||Epoch_E_Loss:0.3232
# timer:  1.9277 sec.
# -------------
# Epoch 133/1500
# -------------
# （train）
# -------------
# epoch 133 || Epoch_D_Loss:0.0498 ||Epoch_G_Loss:0.2558 ||Epoch_E_Loss:0.3005
# timer:  2.3903 sec.
# -------------
# Epoch 134/1500
# -------------
# （train）
# -------------
# epoch 134 || Epoch_D_Loss:0.0502 ||Epoch_G_Loss:0.2807 ||Epoch_E_Loss:0.2856
# timer:  2.3002 sec.
# -------------
# Epoch 135/1500
# -------------
# （train）
# -------------
# epoch 135 || Epoch_D_Loss:0.0505 ||Epoch_G_Loss:0.2350 ||Epoch_E_Loss:0.2757
# timer:  1.9136 sec.
# -------------
# Epoch 136/1500
# -------------
# （train）
# -------------
# epoch 136 || Epoch_D_Loss:0.0552 ||Epoch_G_Loss:0.2614 ||Epoch_E_Loss:0.2514
# timer:  2.2550 sec.
# -------------
# Epoch 137/1500
# -------------
# （train）
# -------------
# epoch 137 || Epoch_D_Loss:0.0494 ||Epoch_G_Loss:0.2632 ||Epoch_E_Loss:0.2615
# timer:  2.6506 sec.
# -------------
# Epoch 138/1500
# -------------
# （train）
# -------------
# epoch 138 || Epoch_D_Loss:0.0468 ||Epoch_G_Loss:0.2500 ||Epoch_E_Loss:0.2956
# timer:  2.0501 sec.
# -------------
# Epoch 139/1500
# -------------
# （train）
# -------------
# epoch 139 || Epoch_D_Loss:0.0446 ||Epoch_G_Loss:0.2482 ||Epoch_E_Loss:0.2905
# timer:  2.2432 sec.
# -------------
# Epoch 140/1500
# -------------
# （train）
# -------------
# epoch 140 || Epoch_D_Loss:0.0495 ||Epoch_G_Loss:0.2725 ||Epoch_E_Loss:0.2616
# timer:  2.4586 sec.
# -------------
# Epoch 141/1500
# -------------
# （train）
# -------------
# epoch 141 || Epoch_D_Loss:0.0818 ||Epoch_G_Loss:0.2409 ||Epoch_E_Loss:0.2886
# timer:  2.0865 sec.
# -------------
# Epoch 142/1500
# -------------
# （train）
# -------------
# epoch 142 || Epoch_D_Loss:0.0745 ||Epoch_G_Loss:0.2307 ||Epoch_E_Loss:0.2565
# timer:  2.4243 sec.
# -------------
# Epoch 143/1500
# -------------
# （train）
# -------------
# epoch 143 || Epoch_D_Loss:0.0568 ||Epoch_G_Loss:0.2337 ||Epoch_E_Loss:0.2873
# timer:  2.1798 sec.
# -------------
# Epoch 144/1500
# -------------
# （train）
# -------------
# epoch 144 || Epoch_D_Loss:0.0499 ||Epoch_G_Loss:0.2512 ||Epoch_E_Loss:0.2695
# timer:  2.1016 sec.
# -------------
# Epoch 145/1500
# -------------
# （train）
# -------------
# epoch 145 || Epoch_D_Loss:0.0476 ||Epoch_G_Loss:0.2681 ||Epoch_E_Loss:0.2672
# timer:  2.6413 sec.
# -------------
# Epoch 146/1500
# -------------
# （train）
# -------------
# epoch 146 || Epoch_D_Loss:0.0490 ||Epoch_G_Loss:0.2566 ||Epoch_E_Loss:0.2673
# timer:  2.1972 sec.
# -------------
# Epoch 147/1500
# -------------
# （train）
# -------------
# epoch 147 || Epoch_D_Loss:0.0491 ||Epoch_G_Loss:0.2212 ||Epoch_E_Loss:0.2644
# timer:  2.3133 sec.
# -------------
# Epoch 148/1500
# -------------
# （train）
# -------------
# epoch 148 || Epoch_D_Loss:0.0538 ||Epoch_G_Loss:0.2284 ||Epoch_E_Loss:0.2417
# timer:  2.4642 sec.
# -------------
# Epoch 149/1500
# -------------
# （train）
# -------------
# epoch 149 || Epoch_D_Loss:0.0581 ||Epoch_G_Loss:0.2157 ||Epoch_E_Loss:0.2326
# timer:  2.0542 sec.
# -------------
# Epoch 150/1500
# -------------
# （train）
# -------------
# epoch 150 || Epoch_D_Loss:0.0549 ||Epoch_G_Loss:0.2247 ||Epoch_E_Loss:0.2358
# timer:  2.4671 sec.
# -------------
# Epoch 151/1500
# -------------
# （train）
# -------------
# epoch 151 || Epoch_D_Loss:0.0636 ||Epoch_G_Loss:0.2010 ||Epoch_E_Loss:0.2359
# timer:  2.5610 sec.
# -------------
# Epoch 152/1500
# -------------
# （train）
# -------------
# epoch 152 || Epoch_D_Loss:0.0725 ||Epoch_G_Loss:0.1977 ||Epoch_E_Loss:0.2273
# timer:  2.1072 sec.
# -------------
# Epoch 153/1500
# -------------
# （train）
# -------------
# epoch 153 || Epoch_D_Loss:0.0535 ||Epoch_G_Loss:0.2284 ||Epoch_E_Loss:0.2448
# timer:  2.3381 sec.
# -------------
# Epoch 154/1500
# -------------
# （train）
# -------------
# epoch 154 || Epoch_D_Loss:0.0478 ||Epoch_G_Loss:0.2703 ||Epoch_E_Loss:0.2459
# timer:  1.9558 sec.
# -------------
# Epoch 155/1500
# -------------
# （train）
# -------------
# epoch 155 || Epoch_D_Loss:0.0435 ||Epoch_G_Loss:0.2739 ||Epoch_E_Loss:0.2610
# timer:  2.0711 sec.
# -------------
# Epoch 156/1500
# -------------
# （train）
# -------------
# epoch 156 || Epoch_D_Loss:0.0539 ||Epoch_G_Loss:0.2199 ||Epoch_E_Loss:0.2472
# timer:  2.3871 sec.
# -------------
# Epoch 157/1500
# -------------
# （train）
# -------------
# epoch 157 || Epoch_D_Loss:0.0891 ||Epoch_G_Loss:0.2506 ||Epoch_E_Loss:0.2214
# timer:  2.4114 sec.
# -------------
# Epoch 158/1500
# -------------
# （train）
# -------------
# epoch 158 || Epoch_D_Loss:0.0794 ||Epoch_G_Loss:0.2102 ||Epoch_E_Loss:0.1901
# timer:  1.9178 sec.
# -------------
# Epoch 159/1500
# -------------
# （train）
# -------------
# epoch 159 || Epoch_D_Loss:0.0885 ||Epoch_G_Loss:0.1947 ||Epoch_E_Loss:0.2096
# timer:  2.2667 sec.
# -------------
# Epoch 160/1500
# -------------
# （train）
# -------------
# epoch 160 || Epoch_D_Loss:0.0845 ||Epoch_G_Loss:0.1968 ||Epoch_E_Loss:0.2126
# timer:  2.4586 sec.
# -------------
# Epoch 161/1500
# -------------
# （train）
# -------------
# epoch 161 || Epoch_D_Loss:0.0930 ||Epoch_G_Loss:0.2048 ||Epoch_E_Loss:0.1877
# timer:  1.9970 sec.
# -------------
# Epoch 162/1500
# -------------
# （train）
# -------------
# epoch 162 || Epoch_D_Loss:0.0919 ||Epoch_G_Loss:0.2180 ||Epoch_E_Loss:0.1870
# timer:  2.3884 sec.
# -------------
# Epoch 163/1500
# -------------
# （train）
# -------------
# epoch 163 || Epoch_D_Loss:0.0653 ||Epoch_G_Loss:0.2121 ||Epoch_E_Loss:0.2313
# timer:  2.2516 sec.
# -------------
# Epoch 164/1500
# -------------
# （train）
# -------------
# epoch 164 || Epoch_D_Loss:0.0662 ||Epoch_G_Loss:0.2119 ||Epoch_E_Loss:0.2144
# timer:  2.1778 sec.
# -------------
# Epoch 165/1500
# -------------
# （train）
# -------------
# epoch 165 || Epoch_D_Loss:0.0813 ||Epoch_G_Loss:0.1813 ||Epoch_E_Loss:0.1973
# timer:  2.4918 sec.
# -------------
# Epoch 166/1500
# -------------
# （train）
# -------------
# epoch 166 || Epoch_D_Loss:0.0940 ||Epoch_G_Loss:0.1608 ||Epoch_E_Loss:0.1840
# timer:  2.0705 sec.
# -------------
# Epoch 167/1500
# -------------
# （train）
# -------------
# epoch 167 || Epoch_D_Loss:0.1006 ||Epoch_G_Loss:0.1800 ||Epoch_E_Loss:0.1932
# timer:  2.6585 sec.
# -------------
# Epoch 168/1500
# -------------
# （train）
# -------------
# epoch 168 || Epoch_D_Loss:0.0707 ||Epoch_G_Loss:0.2115 ||Epoch_E_Loss:0.2079
# timer:  2.1451 sec.
# -------------
# Epoch 169/1500
# -------------
# （train）
# -------------
# epoch 169 || Epoch_D_Loss:0.0665 ||Epoch_G_Loss:0.2301 ||Epoch_E_Loss:0.2087
# timer:  2.2829 sec.
# -------------
# Epoch 170/1500
# -------------
# （train）
# -------------
# epoch 170 || Epoch_D_Loss:0.0641 ||Epoch_G_Loss:0.2153 ||Epoch_E_Loss:0.2508
# timer:  2.1629 sec.
# -------------
# Epoch 171/1500
# -------------
# （train）
# -------------
# epoch 171 || Epoch_D_Loss:0.0669 ||Epoch_G_Loss:0.2355 ||Epoch_E_Loss:0.2153
# timer:  1.9370 sec.
# -------------
# Epoch 172/1500
# -------------
# （train）
# -------------
# epoch 172 || Epoch_D_Loss:0.0597 ||Epoch_G_Loss:0.2352 ||Epoch_E_Loss:0.2240
# timer:  2.1295 sec.
# -------------
# Epoch 173/1500
# -------------
# （train）
# -------------
# epoch 173 || Epoch_D_Loss:0.0616 ||Epoch_G_Loss:0.2248 ||Epoch_E_Loss:0.2231
# timer:  2.4717 sec.
# -------------
# Epoch 174/1500
# -------------
# （train）
# -------------
# epoch 174 || Epoch_D_Loss:0.0617 ||Epoch_G_Loss:0.2387 ||Epoch_E_Loss:0.2232
# timer:  2.2092 sec.
# -------------
# Epoch 175/1500
# -------------
# （train）
# -------------
# epoch 175 || Epoch_D_Loss:0.0665 ||Epoch_G_Loss:0.2066 ||Epoch_E_Loss:0.2133
# timer:  2.3319 sec.
# -------------
# Epoch 176/1500
# -------------
# （train）
# -------------
# epoch 176 || Epoch_D_Loss:0.0686 ||Epoch_G_Loss:0.1681 ||Epoch_E_Loss:0.2294
# timer:  2.4776 sec.
# -------------
# Epoch 177/1500
# -------------
# （train）
# -------------
# epoch 177 || Epoch_D_Loss:0.0925 ||Epoch_G_Loss:0.1888 ||Epoch_E_Loss:0.1942
# timer:  2.1214 sec.
# -------------
# Epoch 178/1500
# -------------
# （train）
# -------------
# epoch 178 || Epoch_D_Loss:0.0862 ||Epoch_G_Loss:0.1932 ||Epoch_E_Loss:0.1921
# timer:  2.4622 sec.
# -------------
# Epoch 179/1500
# -------------
# （train）
# -------------
# epoch 179 || Epoch_D_Loss:0.0788 ||Epoch_G_Loss:0.1773 ||Epoch_E_Loss:0.1944
# timer:  2.0790 sec.
# -------------
# Epoch 180/1500
# -------------
# （train）
# -------------
# epoch 180 || Epoch_D_Loss:0.0689 ||Epoch_G_Loss:0.2009 ||Epoch_E_Loss:0.2011
# timer:  2.0174 sec.
# -------------
# Epoch 181/1500
# -------------
# （train）
# -------------
# epoch 181 || Epoch_D_Loss:0.0665 ||Epoch_G_Loss:0.1868 ||Epoch_E_Loss:0.2200
# timer:  2.3351 sec.
# -------------
# Epoch 182/1500
# -------------
# （train）
# -------------
# epoch 182 || Epoch_D_Loss:0.0899 ||Epoch_G_Loss:0.2131 ||Epoch_E_Loss:0.1892
# timer:  1.8798 sec.
# -------------
# Epoch 183/1500
# -------------
# （train）
# -------------
# epoch 183 || Epoch_D_Loss:0.0902 ||Epoch_G_Loss:0.1821 ||Epoch_E_Loss:0.1701
# timer:  1.9631 sec.
# -------------
# Epoch 184/1500
# -------------
# （train）
# -------------
# epoch 184 || Epoch_D_Loss:0.1137 ||Epoch_G_Loss:0.1665 ||Epoch_E_Loss:0.1470
# timer:  2.3285 sec.
# -------------
# Epoch 185/1500
# -------------
# （train）
# -------------
# epoch 185 || Epoch_D_Loss:0.1231 ||Epoch_G_Loss:0.1610 ||Epoch_E_Loss:0.1565
# timer:  2.3393 sec.
# -------------
# Epoch 186/1500
# -------------
# （train）
# -------------
# epoch 186 || Epoch_D_Loss:0.1117 ||Epoch_G_Loss:0.1521 ||Epoch_E_Loss:0.1627
# timer:  2.0966 sec.
# -------------
# Epoch 187/1500
# -------------
# （train）
# -------------
# epoch 187 || Epoch_D_Loss:0.1061 ||Epoch_G_Loss:0.1619 ||Epoch_E_Loss:0.1634
# timer:  2.6340 sec.
# -------------
# Epoch 188/1500
# -------------
# （train）
# -------------
# epoch 188 || Epoch_D_Loss:0.0944 ||Epoch_G_Loss:0.1763 ||Epoch_E_Loss:0.1714
# timer:  1.9818 sec.
# -------------
# Epoch 189/1500
# -------------
# （train）
# -------------
# epoch 189 || Epoch_D_Loss:0.0778 ||Epoch_G_Loss:0.1768 ||Epoch_E_Loss:0.1856
# timer:  2.1140 sec.
# -------------
# Epoch 190/1500
# -------------
# （train）
# -------------
# epoch 190 || Epoch_D_Loss:0.0745 ||Epoch_G_Loss:0.1957 ||Epoch_E_Loss:0.1976
# timer:  2.6614 sec.
# -------------
# Epoch 191/1500
# -------------
# （train）
# -------------
# epoch 191 || Epoch_D_Loss:0.0764 ||Epoch_G_Loss:0.1921 ||Epoch_E_Loss:0.1779
# timer:  2.1884 sec.
# -------------
# Epoch 192/1500
# -------------
# （train）
# -------------
# epoch 192 || Epoch_D_Loss:0.0798 ||Epoch_G_Loss:0.1779 ||Epoch_E_Loss:0.1905
# timer:  2.3023 sec.
# -------------
# Epoch 193/1500
# -------------
# （train）
# -------------
# epoch 193 || Epoch_D_Loss:0.0912 ||Epoch_G_Loss:0.1608 ||Epoch_E_Loss:0.1765
# timer:  2.4411 sec.
# -------------
# Epoch 194/1500
# -------------
# （train）
# -------------
# epoch 194 || Epoch_D_Loss:0.0913 ||Epoch_G_Loss:0.1841 ||Epoch_E_Loss:0.1735
# timer:  1.9666 sec.
# -------------
# Epoch 195/1500
# -------------
# （train）
# -------------
# epoch 195 || Epoch_D_Loss:0.0936 ||Epoch_G_Loss:0.1594 ||Epoch_E_Loss:0.1829
# timer:  1.9693 sec.
# -------------
# Epoch 196/1500
# -------------
# （train）
# -------------
# epoch 196 || Epoch_D_Loss:0.1068 ||Epoch_G_Loss:0.1730 ||Epoch_E_Loss:0.1562
# timer:  2.3771 sec.
# -------------
# Epoch 197/1500
# -------------
# （train）
# -------------
# epoch 197 || Epoch_D_Loss:0.1170 ||Epoch_G_Loss:0.1839 ||Epoch_E_Loss:0.1656
# timer:  2.4139 sec.
# -------------
# Epoch 198/1500
# -------------
# （train）
# -------------
# epoch 198 || Epoch_D_Loss:0.1078 ||Epoch_G_Loss:0.1476 ||Epoch_E_Loss:0.1797
# timer:  1.9451 sec.
# -------------
# Epoch 199/1500
# -------------
# （train）
# -------------
# epoch 199 || Epoch_D_Loss:0.0968 ||Epoch_G_Loss:0.1609 ||Epoch_E_Loss:0.1606
# timer:  1.9824 sec.
# -------------
# Epoch 200/1500
# -------------
# （train）
# -------------
# epoch 200 || Epoch_D_Loss:0.0942 ||Epoch_G_Loss:0.1534 ||Epoch_E_Loss:0.1747
# timer:  2.3248 sec.
# -------------
# Epoch 201/1500
# -------------
# （train）
# -------------
# epoch 201 || Epoch_D_Loss:0.1174 ||Epoch_G_Loss:0.1628 ||Epoch_E_Loss:0.1469
# timer:  2.4020 sec.
# -------------
# Epoch 202/1500
# -------------
# （train）
# -------------
# epoch 202 || Epoch_D_Loss:0.1091 ||Epoch_G_Loss:0.1697 ||Epoch_E_Loss:0.1617
# timer:  1.8851 sec.
# -------------
# Epoch 203/1500
# -------------
# （train）
# -------------
# epoch 203 || Epoch_D_Loss:0.1013 ||Epoch_G_Loss:0.1561 ||Epoch_E_Loss:0.1523
# timer:  1.9119 sec.
# -------------
# Epoch 204/1500
# -------------
# （train）
# -------------
# epoch 204 || Epoch_D_Loss:0.1070 ||Epoch_G_Loss:0.1398 ||Epoch_E_Loss:0.1645
# timer:  2.3597 sec.
# -------------
# Epoch 205/1500
# -------------
# （train）
# -------------
# epoch 205 || Epoch_D_Loss:0.1025 ||Epoch_G_Loss:0.1512 ||Epoch_E_Loss:0.1504
# timer:  2.5685 sec.
# -------------
# Epoch 206/1500
# -------------
# （train）
# -------------
# epoch 206 || Epoch_D_Loss:0.1060 ||Epoch_G_Loss:0.1555 ||Epoch_E_Loss:0.1483
# timer:  1.9381 sec.
# -------------
# Epoch 207/1500
# -------------
# （train）
# -------------
# epoch 207 || Epoch_D_Loss:0.0957 ||Epoch_G_Loss:0.1720 ||Epoch_E_Loss:0.1683
# timer:  2.0100 sec.
# -------------
# Epoch 208/1500
# -------------
# （train）
# -------------
# epoch 208 || Epoch_D_Loss:0.0818 ||Epoch_G_Loss:0.1845 ||Epoch_E_Loss:0.1848
# timer:  2.3978 sec.
# -------------
# Epoch 209/1500
# -------------
# （train）
# -------------
# epoch 209 || Epoch_D_Loss:0.0888 ||Epoch_G_Loss:0.1853 ||Epoch_E_Loss:0.1767
# timer:  2.2533 sec.
# -------------
# Epoch 210/1500
# -------------
# （train）
# -------------
# epoch 210 || Epoch_D_Loss:0.1026 ||Epoch_G_Loss:0.1636 ||Epoch_E_Loss:0.1725
# timer:  2.0387 sec.
# -------------
# Epoch 211/1500
# -------------
# （train）
# -------------
# epoch 211 || Epoch_D_Loss:0.1176 ||Epoch_G_Loss:0.1697 ||Epoch_E_Loss:0.1502
# timer:  2.4383 sec.
# -------------
# Epoch 212/1500
# -------------
# （train）
# -------------
# epoch 212 || Epoch_D_Loss:0.1154 ||Epoch_G_Loss:0.1552 ||Epoch_E_Loss:0.1643
# timer:  2.5423 sec.
# -------------
# Epoch 213/1500
# -------------
# （train）
# -------------
# epoch 213 || Epoch_D_Loss:0.1011 ||Epoch_G_Loss:0.1568 ||Epoch_E_Loss:0.1698
# timer:  1.9406 sec.
# -------------
# Epoch 214/1500
# -------------
# （train）
# -------------
# epoch 214 || Epoch_D_Loss:0.0975 ||Epoch_G_Loss:0.1611 ||Epoch_E_Loss:0.1758
# timer:  2.0075 sec.
# -------------
# Epoch 215/1500
# -------------
# （train）
# -------------
# epoch 215 || Epoch_D_Loss:0.0971 ||Epoch_G_Loss:0.1659 ||Epoch_E_Loss:0.1762
# timer:  2.3407 sec.
# -------------
# Epoch 216/1500
# -------------
# （train）
# -------------
# epoch 216 || Epoch_D_Loss:0.1085 ||Epoch_G_Loss:0.1458 ||Epoch_E_Loss:0.1704
# timer:  2.2652 sec.
# -------------
# Epoch 217/1500
# -------------
# （train）
# -------------
# epoch 217 || Epoch_D_Loss:0.1097 ||Epoch_G_Loss:0.1584 ||Epoch_E_Loss:0.1674
# timer:  1.9200 sec.
# -------------
# Epoch 218/1500
# -------------
# （train）
# -------------
# epoch 218 || Epoch_D_Loss:0.1080 ||Epoch_G_Loss:0.1424 ||Epoch_E_Loss:0.1702
# timer:  2.3213 sec.
# -------------
# Epoch 219/1500
# -------------
# （train）
# -------------
# epoch 219 || Epoch_D_Loss:0.1090 ||Epoch_G_Loss:0.1551 ||Epoch_E_Loss:0.1727
# timer:  2.5495 sec.
# -------------
# Epoch 220/1500
# -------------
# （train）
# -------------
# epoch 220 || Epoch_D_Loss:0.1011 ||Epoch_G_Loss:0.1544 ||Epoch_E_Loss:0.1793
# timer:  1.8999 sec.
# -------------
# Epoch 221/1500
# -------------
# （train）
# -------------
# epoch 221 || Epoch_D_Loss:0.1076 ||Epoch_G_Loss:0.1462 ||Epoch_E_Loss:0.1745
# timer:  1.9362 sec.
# -------------
# Epoch 222/1500
# -------------
# （train）
# -------------
# epoch 222 || Epoch_D_Loss:0.1135 ||Epoch_G_Loss:0.1471 ||Epoch_E_Loss:0.1786
# timer:  2.2975 sec.
# -------------
# Epoch 223/1500
# -------------
# （train）
# -------------
# epoch 223 || Epoch_D_Loss:0.0994 ||Epoch_G_Loss:0.1523 ||Epoch_E_Loss:0.1930
# timer:  2.3160 sec.
# -------------
# Epoch 224/1500
# -------------
# （train）
# -------------
# epoch 224 || Epoch_D_Loss:0.1103 ||Epoch_G_Loss:0.1440 ||Epoch_E_Loss:0.1907
# timer:  2.1883 sec.
# -------------
# Epoch 225/1500
# -------------
# （train）
# -------------
# epoch 225 || Epoch_D_Loss:0.1217 ||Epoch_G_Loss:0.1436 ||Epoch_E_Loss:0.1876
# timer:  2.2199 sec.
# -------------
# Epoch 226/1500
# -------------
# （train）
# -------------
# epoch 226 || Epoch_D_Loss:0.1275 ||Epoch_G_Loss:0.1385 ||Epoch_E_Loss:0.1959
# timer:  1.9391 sec.
# -------------
# Epoch 227/1500
# -------------
# （train）
# -------------
# epoch 227 || Epoch_D_Loss:0.1337 ||Epoch_G_Loss:0.1367 ||Epoch_E_Loss:0.1754
# timer:  2.0425 sec.
# -------------
# Epoch 228/1500
# -------------
# （train）
# -------------
# epoch 228 || Epoch_D_Loss:0.1219 ||Epoch_G_Loss:0.1250 ||Epoch_E_Loss:0.1872
# timer:  2.4617 sec.
# -------------
# Epoch 229/1500
# -------------
# （train）
# -------------
# epoch 229 || Epoch_D_Loss:0.1359 ||Epoch_G_Loss:0.1392 ||Epoch_E_Loss:0.1605
# timer:  2.3452 sec.
# -------------
# Epoch 230/1500
# -------------
# （train）
# -------------
# epoch 230 || Epoch_D_Loss:0.1281 ||Epoch_G_Loss:0.1456 ||Epoch_E_Loss:0.1429
# timer:  1.9344 sec.
# -------------
# Epoch 231/1500
# -------------
# （train）
# -------------
# epoch 231 || Epoch_D_Loss:0.1531 ||Epoch_G_Loss:0.1198 ||Epoch_E_Loss:0.1362
# timer:  2.2348 sec.
# -------------
# Epoch 232/1500
# -------------
# （train）
# -------------
# epoch 232 || Epoch_D_Loss:0.1372 ||Epoch_G_Loss:0.1265 ||Epoch_E_Loss:0.1324
# timer:  2.3297 sec.
# -------------
# Epoch 233/1500
# -------------
# （train）
# -------------
# epoch 233 || Epoch_D_Loss:0.1316 ||Epoch_G_Loss:0.1273 ||Epoch_E_Loss:0.1230
# timer:  2.0518 sec.
# -------------
# Epoch 234/1500
# -------------
# （train）
# -------------
# epoch 234 || Epoch_D_Loss:0.1222 ||Epoch_G_Loss:0.1311 ||Epoch_E_Loss:0.1362
# timer:  2.1735 sec.
# -------------
# Epoch 235/1500
# -------------
# （train）
# -------------
# epoch 235 || Epoch_D_Loss:0.1123 ||Epoch_G_Loss:0.1372 ||Epoch_E_Loss:0.1363
# timer:  2.5210 sec.
# -------------
# Epoch 236/1500
# -------------
# （train）
# -------------
# epoch 236 || Epoch_D_Loss:0.1086 ||Epoch_G_Loss:0.1536 ||Epoch_E_Loss:0.1319
# timer:  1.9526 sec.
# -------------
# Epoch 237/1500
# -------------
# （train）
# -------------
# epoch 237 || Epoch_D_Loss:0.1139 ||Epoch_G_Loss:0.1409 ||Epoch_E_Loss:0.1297
# timer:  2.1898 sec.
# -------------
# Epoch 238/1500
# -------------
# （train）
# -------------
# epoch 238 || Epoch_D_Loss:0.1144 ||Epoch_G_Loss:0.1300 ||Epoch_E_Loss:0.1277
# timer:  2.5215 sec.
# -------------
# Epoch 239/1500
# -------------
# （train）
# -------------
# epoch 239 || Epoch_D_Loss:0.1170 ||Epoch_G_Loss:0.1361 ||Epoch_E_Loss:0.1200
# timer:  2.0768 sec.
# -------------
# Epoch 240/1500
# -------------
# （train）
# -------------
# epoch 240 || Epoch_D_Loss:0.1274 ||Epoch_G_Loss:0.1268 ||Epoch_E_Loss:0.1281
# timer:  2.0791 sec.
# -------------
# Epoch 241/1500
# -------------
# （train）
# -------------
# epoch 241 || Epoch_D_Loss:0.1125 ||Epoch_G_Loss:0.1437 ||Epoch_E_Loss:0.1282
# timer:  2.6053 sec.
# -------------
# Epoch 242/1500
# -------------
# （train）
# -------------
# epoch 242 || Epoch_D_Loss:0.1202 ||Epoch_G_Loss:0.1452 ||Epoch_E_Loss:0.1298
# timer:  2.1142 sec.
# -------------
# Epoch 243/1500
# -------------
# （train）
# -------------
# epoch 243 || Epoch_D_Loss:0.1228 ||Epoch_G_Loss:0.1312 ||Epoch_E_Loss:0.1367
# timer:  2.4277 sec.
# -------------
# Epoch 244/1500
# -------------
# （train）
# -------------
# epoch 244 || Epoch_D_Loss:0.1126 ||Epoch_G_Loss:0.1423 ||Epoch_E_Loss:0.1327
# timer:  2.3525 sec.
# -------------
# Epoch 245/1500
# -------------
# （train）
# -------------
# epoch 245 || Epoch_D_Loss:0.1214 ||Epoch_G_Loss:0.1496 ||Epoch_E_Loss:0.1250
# timer:  2.2105 sec.
# -------------
# Epoch 246/1500
# -------------
# （train）
# -------------
# epoch 246 || Epoch_D_Loss:0.1203 ||Epoch_G_Loss:0.1178 ||Epoch_E_Loss:0.1307
# timer:  2.4965 sec.
# -------------
# Epoch 247/1500
# -------------
# （train）
# -------------
# epoch 247 || Epoch_D_Loss:0.1316 ||Epoch_G_Loss:0.1252 ||Epoch_E_Loss:0.1105
# timer:  2.0450 sec.
# -------------
# Epoch 248/1500
# -------------
# （train）
# -------------
# epoch 248 || Epoch_D_Loss:0.1449 ||Epoch_G_Loss:0.1136 ||Epoch_E_Loss:0.1067
# timer:  1.9588 sec.
# -------------
# Epoch 249/1500
# -------------
# （train）
# -------------
# epoch 249 || Epoch_D_Loss:0.1339 ||Epoch_G_Loss:0.1059 ||Epoch_E_Loss:0.1119
# timer:  2.2206 sec.
# -------------
# Epoch 250/1500
# -------------
# （train）
# -------------
# epoch 250 || Epoch_D_Loss:0.1248 ||Epoch_G_Loss:0.1270 ||Epoch_E_Loss:0.1146
# timer:  2.3307 sec.
# -------------
# Epoch 251/1500
# -------------
# （train）
# -------------
# epoch 251 || Epoch_D_Loss:0.1133 ||Epoch_G_Loss:0.1300 ||Epoch_E_Loss:0.1272
# timer:  1.9390 sec.
# -------------
# Epoch 252/1500
# -------------
# （train）
# -------------
# epoch 252 || Epoch_D_Loss:0.1128 ||Epoch_G_Loss:0.1402 ||Epoch_E_Loss:0.1261
# timer:  2.3062 sec.
# -------------
# Epoch 253/1500
# -------------
# （train）
# -------------
# epoch 253 || Epoch_D_Loss:0.0979 ||Epoch_G_Loss:0.1275 ||Epoch_E_Loss:0.1401
# timer:  2.1535 sec.
# -------------
# Epoch 254/1500
# -------------
# （train）
# -------------
# epoch 254 || Epoch_D_Loss:0.1025 ||Epoch_G_Loss:0.1457 ||Epoch_E_Loss:0.1322
# timer:  1.9428 sec.
# -------------
# Epoch 255/1500
# -------------
# （train）
# -------------
# epoch 255 || Epoch_D_Loss:0.1050 ||Epoch_G_Loss:0.1449 ||Epoch_E_Loss:0.1323
# timer:  2.1957 sec.
# -------------
# Epoch 256/1500
# -------------
# （train）
# -------------
# epoch 256 || Epoch_D_Loss:0.1209 ||Epoch_G_Loss:0.1196 ||Epoch_E_Loss:0.1270
# timer:  2.4135 sec.
# -------------
# Epoch 257/1500
# -------------
# （train）
# -------------
# epoch 257 || Epoch_D_Loss:0.1350 ||Epoch_G_Loss:0.1198 ||Epoch_E_Loss:0.1087
# timer:  1.8935 sec.
# -------------
# Epoch 258/1500
# -------------
# （train）
# -------------
# epoch 258 || Epoch_D_Loss:0.1417 ||Epoch_G_Loss:0.1053 ||Epoch_E_Loss:0.1021
# timer:  2.2026 sec.
# -------------
# Epoch 259/1500
# -------------
# （train）
# -------------
# epoch 259 || Epoch_D_Loss:0.1356 ||Epoch_G_Loss:0.1086 ||Epoch_E_Loss:0.1074
# timer:  2.4176 sec.
# -------------
# Epoch 260/1500
# -------------
# （train）
# -------------
# epoch 260 || Epoch_D_Loss:0.1311 ||Epoch_G_Loss:0.1152 ||Epoch_E_Loss:0.1198
# timer:  2.0321 sec.
# -------------
# Epoch 261/1500
# -------------
# （train）
# -------------
# epoch 261 || Epoch_D_Loss:0.1243 ||Epoch_G_Loss:0.1275 ||Epoch_E_Loss:0.1216
# timer:  2.5603 sec.
# -------------
# Epoch 262/1500
# -------------
# （train）
# -------------
# epoch 262 || Epoch_D_Loss:0.1168 ||Epoch_G_Loss:0.1296 ||Epoch_E_Loss:0.1251
# timer:  2.0648 sec.
# -------------
# Epoch 263/1500
# -------------
# （train）
# -------------
# epoch 263 || Epoch_D_Loss:0.1144 ||Epoch_G_Loss:0.1325 ||Epoch_E_Loss:0.1225
# timer:  2.1509 sec.
# -------------
# Epoch 264/1500
# -------------
# （train）
# -------------
# epoch 264 || Epoch_D_Loss:0.1133 ||Epoch_G_Loss:0.1164 ||Epoch_E_Loss:0.1337
# timer:  2.5477 sec.
# -------------
# Epoch 265/1500
# -------------
# （train）
# -------------
# epoch 265 || Epoch_D_Loss:0.1104 ||Epoch_G_Loss:0.1392 ||Epoch_E_Loss:0.1268
# timer:  2.1160 sec.
# -------------
# Epoch 266/1500
# -------------
# （train）
# -------------
# epoch 266 || Epoch_D_Loss:0.1253 ||Epoch_G_Loss:0.1235 ||Epoch_E_Loss:0.1202
# timer:  2.3246 sec.
# -------------
# Epoch 267/1500
# -------------
# （train）
# -------------
# epoch 267 || Epoch_D_Loss:0.1386 ||Epoch_G_Loss:0.1048 ||Epoch_E_Loss:0.1104
# timer:  1.8508 sec.
# -------------
# Epoch 268/1500
# -------------
# （train）
# -------------
# epoch 268 || Epoch_D_Loss:0.1367 ||Epoch_G_Loss:0.1065 ||Epoch_E_Loss:0.1108
# timer:  1.8935 sec.
# -------------
# Epoch 269/1500
# -------------
# （train）
# -------------
# epoch 269 || Epoch_D_Loss:0.1248 ||Epoch_G_Loss:0.1199 ||Epoch_E_Loss:0.1247
# timer:  2.2025 sec.
# -------------
# Epoch 270/1500
# -------------
# （train）
# -------------
# epoch 270 || Epoch_D_Loss:0.1120 ||Epoch_G_Loss:0.1233 ||Epoch_E_Loss:0.1358
# timer:  2.6781 sec.
# -------------
# Epoch 271/1500
# -------------
# （train）
# -------------
# epoch 271 || Epoch_D_Loss:0.1117 ||Epoch_G_Loss:0.1348 ||Epoch_E_Loss:0.1334
# timer:  1.9346 sec.
# -------------
# Epoch 272/1500
# -------------
# （train）
# -------------
# epoch 272 || Epoch_D_Loss:0.1181 ||Epoch_G_Loss:0.1254 ||Epoch_E_Loss:0.1279
# timer:  2.2852 sec.
# -------------
# Epoch 273/1500
# -------------
# （train）
# -------------
# epoch 273 || Epoch_D_Loss:0.1243 ||Epoch_G_Loss:0.1187 ||Epoch_E_Loss:0.1231
# timer:  1.8696 sec.
# -------------
# Epoch 274/1500
# -------------
# （train）
# -------------
# epoch 274 || Epoch_D_Loss:0.1220 ||Epoch_G_Loss:0.1223 ||Epoch_E_Loss:0.1192
# timer:  2.0190 sec.
# -------------
# Epoch 275/1500
# -------------
# （train）
# -------------
# epoch 275 || Epoch_D_Loss:0.1279 ||Epoch_G_Loss:0.1135 ||Epoch_E_Loss:0.1255
# timer:  2.3130 sec.
# -------------
# Epoch 276/1500
# -------------
# （train）
# -------------
# epoch 276 || Epoch_D_Loss:0.1278 ||Epoch_G_Loss:0.1322 ||Epoch_E_Loss:0.1142
# timer:  2.3085 sec.
# -------------
# Epoch 277/1500
# -------------
# （train）
# -------------
# epoch 277 || Epoch_D_Loss:0.1177 ||Epoch_G_Loss:0.1234 ||Epoch_E_Loss:0.1278
# timer:  1.9932 sec.
# -------------
# Epoch 278/1500
# -------------
# （train）
# -------------
# epoch 278 || Epoch_D_Loss:0.1161 ||Epoch_G_Loss:0.1452 ||Epoch_E_Loss:0.1223
# timer:  2.2361 sec.
# -------------
# Epoch 279/1500
# -------------
# （train）
# -------------
# epoch 279 || Epoch_D_Loss:0.1054 ||Epoch_G_Loss:0.1365 ||Epoch_E_Loss:0.1365
# timer:  2.5861 sec.
# -------------
# Epoch 280/1500
# -------------
# （train）
# -------------
# epoch 280 || Epoch_D_Loss:0.1069 ||Epoch_G_Loss:0.1461 ||Epoch_E_Loss:0.1273
# timer:  1.8973 sec.
# -------------
# Epoch 281/1500
# -------------
# （train）
# -------------
# epoch 281 || Epoch_D_Loss:0.1188 ||Epoch_G_Loss:0.1128 ||Epoch_E_Loss:0.1290
# timer:  2.0555 sec.
# -------------
# Epoch 282/1500
# -------------
# （train）
# -------------
# epoch 282 || Epoch_D_Loss:0.1227 ||Epoch_G_Loss:0.1265 ||Epoch_E_Loss:0.1211
# timer:  2.2606 sec.
# -------------
# Epoch 283/1500
# -------------
# （train）
# -------------
# epoch 283 || Epoch_D_Loss:0.1044 ||Epoch_G_Loss:0.1324 ||Epoch_E_Loss:0.1341
# timer:  2.3170 sec.
# -------------
# Epoch 284/1500
# -------------
# （train）
# -------------
# epoch 284 || Epoch_D_Loss:0.1086 ||Epoch_G_Loss:0.1220 ||Epoch_E_Loss:0.1355
# timer:  1.9485 sec.
# -------------
# Epoch 285/1500
# -------------
# （train）
# -------------
# epoch 285 || Epoch_D_Loss:0.1092 ||Epoch_G_Loss:0.1292 ||Epoch_E_Loss:0.1303
# timer:  2.3523 sec.
# -------------
# Epoch 286/1500
# -------------
# （train）
# -------------
# epoch 286 || Epoch_D_Loss:0.1243 ||Epoch_G_Loss:0.1274 ||Epoch_E_Loss:0.1245
# timer:  2.1657 sec.
# -------------
# Epoch 287/1500
# -------------
# （train）
# -------------
# epoch 287 || Epoch_D_Loss:0.1262 ||Epoch_G_Loss:0.1166 ||Epoch_E_Loss:0.1361
# timer:  1.9401 sec.
# -------------
# Epoch 288/1500
# -------------
# （train）
# -------------
# epoch 288 || Epoch_D_Loss:0.1281 ||Epoch_G_Loss:0.1244 ||Epoch_E_Loss:0.1262
# timer:  2.2086 sec.
# -------------
# Epoch 289/1500
# -------------
# （train）
# -------------
# epoch 289 || Epoch_D_Loss:0.1285 ||Epoch_G_Loss:0.1158 ||Epoch_E_Loss:0.1249
# timer:  2.4241 sec.
# -------------
# Epoch 290/1500
# -------------
# （train）
# -------------
# epoch 290 || Epoch_D_Loss:0.1330 ||Epoch_G_Loss:0.1275 ||Epoch_E_Loss:0.1250
# timer:  2.0748 sec.
# -------------
# Epoch 291/1500
# -------------
# （train）
# -------------
# epoch 291 || Epoch_D_Loss:0.1497 ||Epoch_G_Loss:0.0975 ||Epoch_E_Loss:0.1119
# timer:  1.9895 sec.
# -------------
# Epoch 292/1500
# -------------
# （train）
# -------------
# epoch 292 || Epoch_D_Loss:0.1405 ||Epoch_G_Loss:0.1207 ||Epoch_E_Loss:0.1078
# timer:  2.2119 sec.
# -------------
# Epoch 293/1500
# -------------
# （train）
# -------------
# epoch 293 || Epoch_D_Loss:0.1372 ||Epoch_G_Loss:0.1188 ||Epoch_E_Loss:0.1104
# timer:  2.3684 sec.
# -------------
# Epoch 294/1500
# -------------
# （train）
# -------------
# epoch 294 || Epoch_D_Loss:0.1388 ||Epoch_G_Loss:0.1130 ||Epoch_E_Loss:0.1065
# timer:  1.9441 sec.
# -------------
# Epoch 295/1500
# -------------
# （train）
# -------------
# epoch 295 || Epoch_D_Loss:0.1383 ||Epoch_G_Loss:0.1059 ||Epoch_E_Loss:0.1065
# timer:  2.3953 sec.
# -------------
# Epoch 296/1500
# -------------
# （train）
# -------------
# epoch 296 || Epoch_D_Loss:0.1294 ||Epoch_G_Loss:0.1189 ||Epoch_E_Loss:0.1105
# timer:  2.3370 sec.
# -------------
# Epoch 297/1500
# -------------
# （train）
# -------------
# ...
# timer:  2.3532 sec.
# -------------
# Epoch 1403/1500
# -------------
# （train）
# -------------
# epoch 1403 || Epoch_D_Loss:0.1502 ||Epoch_G_Loss:0.1061 ||Epoch_E_Loss:0.1271
# timer:  1.9365 sec.
# -------------
# Epoch 1404/1500
# -------------
# （train）
# -------------
# epoch 1404 || Epoch_D_Loss:0.1544 ||Epoch_G_Loss:0.1108 ||Epoch_E_Loss:0.1241
# timer:  2.5719 sec.
# -------------
# Epoch 1405/1500
# -------------
# （train）
# -------------
# epoch 1405 || Epoch_D_Loss:0.1735 ||Epoch_G_Loss:0.0874 ||Epoch_E_Loss:0.1118
# timer:  2.1157 sec.
# -------------
# Epoch 1406/1500
# -------------
# （train）
# -------------
# epoch 1406 || Epoch_D_Loss:0.1820 ||Epoch_G_Loss:0.0798 ||Epoch_E_Loss:0.1024
# timer:  2.1605 sec.
# -------------
# Epoch 1407/1500
# -------------
# （train）
# -------------
# epoch 1407 || Epoch_D_Loss:0.1799 ||Epoch_G_Loss:0.0860 ||Epoch_E_Loss:0.1043
# timer:  2.3682 sec.
# -------------
# Epoch 1408/1500
# -------------
# （train）
# -------------
# epoch 1408 || Epoch_D_Loss:0.1646 ||Epoch_G_Loss:0.0894 ||Epoch_E_Loss:0.1074
# timer:  1.8872 sec.
# -------------
# Epoch 1409/1500
# -------------
# （train）
# -------------
# epoch 1409 || Epoch_D_Loss:0.1393 ||Epoch_G_Loss:0.1035 ||Epoch_E_Loss:0.1232
# timer:  1.9743 sec.
# -------------
# Epoch 1410/1500
# -------------
# （train）
# -------------
# epoch 1410 || Epoch_D_Loss:0.1320 ||Epoch_G_Loss:0.1247 ||Epoch_E_Loss:0.1212
# timer:  2.3141 sec.
# -------------
# Epoch 1411/1500
# -------------
# （train）
# -------------
# epoch 1411 || Epoch_D_Loss:0.1297 ||Epoch_G_Loss:0.1046 ||Epoch_E_Loss:0.1262
# timer:  2.2316 sec.
# -------------
# Epoch 1412/1500
# -------------
# （train）
# -------------
# epoch 1412 || Epoch_D_Loss:0.1423 ||Epoch_G_Loss:0.1035 ||Epoch_E_Loss:0.1195
# timer:  1.9734 sec.
# -------------
# Epoch 1413/1500
# -------------
# （train）
# -------------
# epoch 1413 || Epoch_D_Loss:0.1706 ||Epoch_G_Loss:0.1051 ||Epoch_E_Loss:0.1015
# timer:  2.1376 sec.
# -------------
# Epoch 1414/1500
# -------------
# （train）
# -------------
# epoch 1414 || Epoch_D_Loss:0.1664 ||Epoch_G_Loss:0.0855 ||Epoch_E_Loss:0.1091
# timer:  2.6040 sec.
# -------------
# Epoch 1415/1500
# -------------
# （train）
# -------------
# epoch 1415 || Epoch_D_Loss:0.1499 ||Epoch_G_Loss:0.0943 ||Epoch_E_Loss:0.1150
# timer:  2.2847 sec.
# -------------
# Epoch 1416/1500
# -------------
# （train）
# -------------
# epoch 1416 || Epoch_D_Loss:0.1290 ||Epoch_G_Loss:0.1168 ||Epoch_E_Loss:0.1220
# timer:  1.9106 sec.
# -------------
# Epoch 1417/1500
# -------------
# （train）
# -------------
# epoch 1417 || Epoch_D_Loss:0.1295 ||Epoch_G_Loss:0.1108 ||Epoch_E_Loss:0.1265
# timer:  2.1055 sec.
# -------------
# Epoch 1418/1500
# -------------
# （train）
# -------------
# epoch 1418 || Epoch_D_Loss:0.1465 ||Epoch_G_Loss:0.1078 ||Epoch_E_Loss:0.1136
# timer:  2.5909 sec.
# -------------
# Epoch 1419/1500
# -------------
# （train）
# -------------
# epoch 1419 || Epoch_D_Loss:0.1446 ||Epoch_G_Loss:0.0999 ||Epoch_E_Loss:0.1158
# timer:  1.9767 sec.
# -------------
# Epoch 1420/1500
# -------------
# （train）
# -------------
# epoch 1420 || Epoch_D_Loss:0.1492 ||Epoch_G_Loss:0.1072 ||Epoch_E_Loss:0.1113
# timer:  2.5372 sec.
# -------------
# Epoch 1421/1500
# -------------
# （train）
# -------------
# epoch 1421 || Epoch_D_Loss:0.1450 ||Epoch_G_Loss:0.1021 ||Epoch_E_Loss:0.1090
# timer:  2.3083 sec.
# -------------
# Epoch 1422/1500
# -------------
# （train）
# -------------
# epoch 1422 || Epoch_D_Loss:0.1533 ||Epoch_G_Loss:0.0944 ||Epoch_E_Loss:0.1094
# timer:  1.9496 sec.
# -------------
# Epoch 1423/1500
# -------------
# （train）
# -------------
# epoch 1423 || Epoch_D_Loss:0.1609 ||Epoch_G_Loss:0.1003 ||Epoch_E_Loss:0.1004
# timer:  2.5709 sec.
# -------------
# Epoch 1424/1500
# -------------
# （train）
# -------------
# epoch 1424 || Epoch_D_Loss:0.1464 ||Epoch_G_Loss:0.1101 ||Epoch_E_Loss:0.1101
# timer:  2.1386 sec.
# -------------
# Epoch 1425/1500
# -------------
# （train）
# -------------
# epoch 1425 || Epoch_D_Loss:0.1498 ||Epoch_G_Loss:0.0983 ||Epoch_E_Loss:0.1062
# timer:  2.2539 sec.
# -------------
# Epoch 1426/1500
# -------------
# （train）
# -------------
# epoch 1426 || Epoch_D_Loss:0.1724 ||Epoch_G_Loss:0.0962 ||Epoch_E_Loss:0.0964
# timer:  2.3942 sec.
# -------------
# Epoch 1427/1500
# -------------
# （train）
# -------------
# epoch 1427 || Epoch_D_Loss:0.1647 ||Epoch_G_Loss:0.0971 ||Epoch_E_Loss:0.1012
# timer:  2.1861 sec.
# -------------
# Epoch 1428/1500
# -------------
# （train）
# -------------
# epoch 1428 || Epoch_D_Loss:0.1597 ||Epoch_G_Loss:0.1101 ||Epoch_E_Loss:0.1086
# timer:  2.5712 sec.
# -------------
# Epoch 1429/1500
# -------------
# （train）
# -------------
# epoch 1429 || Epoch_D_Loss:0.1600 ||Epoch_G_Loss:0.0943 ||Epoch_E_Loss:0.1105
# timer:  1.9886 sec.
# -------------
# Epoch 1430/1500
# -------------
# （train）
# -------------
# epoch 1430 || Epoch_D_Loss:0.1472 ||Epoch_G_Loss:0.1091 ||Epoch_E_Loss:0.1148
# timer:  2.0332 sec.
# -------------
# Epoch 1431/1500
# -------------
# （train）
# -------------
# epoch 1431 || Epoch_D_Loss:0.1287 ||Epoch_G_Loss:0.1156 ||Epoch_E_Loss:0.1304
# timer:  2.3849 sec.
# -------------
# Epoch 1432/1500
# -------------
# （train）
# -------------
# epoch 1432 || Epoch_D_Loss:0.1305 ||Epoch_G_Loss:0.1160 ||Epoch_E_Loss:0.1226
# timer:  2.3629 sec.
# -------------
# Epoch 1433/1500
# -------------
# （train）
# -------------
# epoch 1433 || Epoch_D_Loss:0.1454 ||Epoch_G_Loss:0.1082 ||Epoch_E_Loss:0.1140
# timer:  2.0940 sec.
# -------------
# Epoch 1434/1500
# -------------
# （train）
# -------------
# epoch 1434 || Epoch_D_Loss:0.1611 ||Epoch_G_Loss:0.1005 ||Epoch_E_Loss:0.0993
# timer:  2.6345 sec.
# -------------
# Epoch 1435/1500
# -------------
# （train）
# -------------
# epoch 1435 || Epoch_D_Loss:0.1769 ||Epoch_G_Loss:0.0854 ||Epoch_E_Loss:0.0946
# timer:  1.8750 sec.
# -------------
# Epoch 1436/1500
# -------------
# （train）
# -------------
# epoch 1436 || Epoch_D_Loss:0.1743 ||Epoch_G_Loss:0.0883 ||Epoch_E_Loss:0.0940
# timer:  2.0136 sec.
# -------------
# Epoch 1437/1500
# -------------
# （train）
# -------------
# epoch 1437 || Epoch_D_Loss:0.1685 ||Epoch_G_Loss:0.0941 ||Epoch_E_Loss:0.0962
# timer:  2.3051 sec.
# -------------
# Epoch 1438/1500
# -------------
# （train）
# -------------
# epoch 1438 || Epoch_D_Loss:0.1645 ||Epoch_G_Loss:0.0975 ||Epoch_E_Loss:0.1038
# timer:  2.1858 sec.
# -------------
# Epoch 1439/1500
# -------------
# （train）
# -------------
# epoch 1439 || Epoch_D_Loss:0.1491 ||Epoch_G_Loss:0.1056 ||Epoch_E_Loss:0.1084
# timer:  2.0607 sec.
# -------------
# Epoch 1440/1500
# -------------
# （train）
# -------------
# epoch 1440 || Epoch_D_Loss:0.1394 ||Epoch_G_Loss:0.1117 ||Epoch_E_Loss:0.1123
# timer:  2.2529 sec.
# -------------
# Epoch 1441/1500
# -------------
# （train）
# -------------
# epoch 1441 || Epoch_D_Loss:0.1388 ||Epoch_G_Loss:0.0980 ||Epoch_E_Loss:0.1137
# timer:  2.5443 sec.
# -------------
# Epoch 1442/1500
# -------------
# （train）
# -------------
# epoch 1442 || Epoch_D_Loss:0.1459 ||Epoch_G_Loss:0.1040 ||Epoch_E_Loss:0.1087
# timer:  2.1213 sec.
# -------------
# Epoch 1443/1500
# -------------
# （train）
# -------------
# epoch 1443 || Epoch_D_Loss:0.1545 ||Epoch_G_Loss:0.0972 ||Epoch_E_Loss:0.1034
# timer:  2.1443 sec.
# -------------
# Epoch 1444/1500
# -------------
# （train）
# -------------
# epoch 1444 || Epoch_D_Loss:0.1523 ||Epoch_G_Loss:0.1039 ||Epoch_E_Loss:0.1017
# timer:  2.5875 sec.
# -------------
# Epoch 1445/1500
# -------------
# （train）
# -------------
# epoch 1445 || Epoch_D_Loss:0.1498 ||Epoch_G_Loss:0.1037 ||Epoch_E_Loss:0.1041
# timer:  2.2858 sec.
# -------------
# Epoch 1446/1500
# -------------
# （train）
# -------------
# epoch 1446 || Epoch_D_Loss:0.1551 ||Epoch_G_Loss:0.0946 ||Epoch_E_Loss:0.1038
# timer:  2.2275 sec.
# -------------
# Epoch 1447/1500
# -------------
# （train）
# -------------
# epoch 1447 || Epoch_D_Loss:0.1444 ||Epoch_G_Loss:0.1022 ||Epoch_E_Loss:0.1102
# timer:  2.3376 sec.
# -------------
# Epoch 1448/1500
# -------------
# （train）
# -------------
# epoch 1448 || Epoch_D_Loss:0.1468 ||Epoch_G_Loss:0.1022 ||Epoch_E_Loss:0.1059
# timer:  1.9487 sec.
# -------------
# Epoch 1449/1500
# -------------
# （train）
# -------------
# epoch 1449 || Epoch_D_Loss:0.1513 ||Epoch_G_Loss:0.1000 ||Epoch_E_Loss:0.1078
# timer:  2.2833 sec.
# -------------
# Epoch 1450/1500
# -------------
# （train）
# -------------
# epoch 1450 || Epoch_D_Loss:0.1381 ||Epoch_G_Loss:0.1024 ||Epoch_E_Loss:0.1191
# timer:  2.1938 sec.
# -------------
# Epoch 1451/1500
# -------------
# （train）
# -------------
# epoch 1451 || Epoch_D_Loss:0.1289 ||Epoch_G_Loss:0.1133 ||Epoch_E_Loss:0.1264
# timer:  2.0303 sec.
# -------------
# Epoch 1452/1500
# -------------
# （train）
# -------------
# epoch 1452 || Epoch_D_Loss:0.1200 ||Epoch_G_Loss:0.1160 ||Epoch_E_Loss:0.1340
# timer:  2.2472 sec.
# -------------
# Epoch 1453/1500
# -------------
# （train）
# -------------
# epoch 1453 || Epoch_D_Loss:0.1248 ||Epoch_G_Loss:0.1199 ||Epoch_E_Loss:0.1258
# timer:  2.3085 sec.
# -------------
# Epoch 1454/1500
# -------------
# （train）
# -------------
# epoch 1454 || Epoch_D_Loss:0.1303 ||Epoch_G_Loss:0.1186 ||Epoch_E_Loss:0.1192
# timer:  1.8991 sec.
# -------------
# Epoch 1455/1500
# -------------
# （train）
# -------------
# epoch 1455 || Epoch_D_Loss:0.1337 ||Epoch_G_Loss:0.1005 ||Epoch_E_Loss:0.1260
# timer:  2.0507 sec.
# -------------
# Epoch 1456/1500
# -------------
# （train）
# -------------
# epoch 1456 || Epoch_D_Loss:0.1397 ||Epoch_G_Loss:0.1066 ||Epoch_E_Loss:0.1167
# timer:  2.4025 sec.
# -------------
# Epoch 1457/1500
# -------------
# （train）
# -------------
# epoch 1457 || Epoch_D_Loss:0.1290 ||Epoch_G_Loss:0.1083 ||Epoch_E_Loss:0.1288
# timer:  2.2336 sec.
# -------------
# Epoch 1458/1500
# -------------
# （train）
# -------------
# epoch 1458 || Epoch_D_Loss:0.1379 ||Epoch_G_Loss:0.1088 ||Epoch_E_Loss:0.1241
# timer:  2.0022 sec.
# -------------
# Epoch 1459/1500
# -------------
# （train）
# -------------
# epoch 1459 || Epoch_D_Loss:0.1372 ||Epoch_G_Loss:0.1126 ||Epoch_E_Loss:0.1184
# timer:  2.4754 sec.
# -------------
# Epoch 1460/1500
# -------------
# （train）
# -------------
# epoch 1460 || Epoch_D_Loss:0.1371 ||Epoch_G_Loss:0.1027 ||Epoch_E_Loss:0.1223
# timer:  1.9303 sec.
# -------------
# Epoch 1461/1500
# -------------
# （train）
# -------------
# epoch 1461 || Epoch_D_Loss:0.1390 ||Epoch_G_Loss:0.1060 ||Epoch_E_Loss:0.1137
# timer:  1.9550 sec.
# -------------
# Epoch 1462/1500
# -------------
# （train）
# -------------
# epoch 1462 || Epoch_D_Loss:0.1440 ||Epoch_G_Loss:0.0952 ||Epoch_E_Loss:0.1171
# timer:  2.2425 sec.
# -------------
# Epoch 1463/1500
# -------------
# （train）
# -------------
# epoch 1463 || Epoch_D_Loss:0.1433 ||Epoch_G_Loss:0.1041 ||Epoch_E_Loss:0.1158
# timer:  2.2480 sec.
# -------------
# Epoch 1464/1500
# -------------
# （train）
# -------------
# epoch 1464 || Epoch_D_Loss:0.1257 ||Epoch_G_Loss:0.1218 ||Epoch_E_Loss:0.1271
# timer:  1.9319 sec.
# -------------
# Epoch 1465/1500
# -------------
# （train）
# -------------
# epoch 1465 || Epoch_D_Loss:0.1149 ||Epoch_G_Loss:0.1219 ||Epoch_E_Loss:0.1457
# timer:  2.3937 sec.
# -------------
# Epoch 1466/1500
# -------------
# （train）
# -------------
# epoch 1466 || Epoch_D_Loss:0.1061 ||Epoch_G_Loss:0.1299 ||Epoch_E_Loss:0.1447
# timer:  2.0799 sec.
# -------------
# Epoch 1467/1500
# -------------
# （train）
# -------------
# epoch 1467 || Epoch_D_Loss:0.1248 ||Epoch_G_Loss:0.1150 ||Epoch_E_Loss:0.1318
# timer:  1.9663 sec.
# -------------
# Epoch 1468/1500
# -------------
# （train）
# -------------
# epoch 1468 || Epoch_D_Loss:0.1411 ||Epoch_G_Loss:0.1082 ||Epoch_E_Loss:0.1199
# timer:  2.1636 sec.
# -------------
# Epoch 1469/1500
# -------------
# （train）
# -------------
# epoch 1469 || Epoch_D_Loss:0.1438 ||Epoch_G_Loss:0.1152 ||Epoch_E_Loss:0.1165
# timer:  2.5735 sec.
# -------------
# Epoch 1470/1500
# -------------
# （train）
# -------------
# epoch 1470 || Epoch_D_Loss:0.1536 ||Epoch_G_Loss:0.1126 ||Epoch_E_Loss:0.1137
# timer:  2.0304 sec.
# -------------
# Epoch 1471/1500
# -------------
# （train）
# -------------
# epoch 1471 || Epoch_D_Loss:0.1430 ||Epoch_G_Loss:0.1089 ||Epoch_E_Loss:0.1233
# timer:  2.3918 sec.
# -------------
# Epoch 1472/1500
# -------------
# （train）
# -------------
# epoch 1472 || Epoch_D_Loss:0.1331 ||Epoch_G_Loss:0.1126 ||Epoch_E_Loss:0.1236
# timer:  1.9415 sec.
# -------------
# Epoch 1473/1500
# -------------
# （train）
# -------------
# epoch 1473 || Epoch_D_Loss:0.1264 ||Epoch_G_Loss:0.1236 ||Epoch_E_Loss:0.1226
# timer:  1.9925 sec.
# -------------
# Epoch 1474/1500
# -------------
# （train）
# -------------
# epoch 1474 || Epoch_D_Loss:0.1248 ||Epoch_G_Loss:0.1150 ||Epoch_E_Loss:0.1262
# timer:  2.3409 sec.
# -------------
# Epoch 1475/1500
# -------------
# （train）
# -------------
# epoch 1475 || Epoch_D_Loss:0.1321 ||Epoch_G_Loss:0.1218 ||Epoch_E_Loss:0.1201
# timer:  2.3686 sec.
# -------------
# Epoch 1476/1500
# -------------
# （train）
# -------------
# epoch 1476 || Epoch_D_Loss:0.1437 ||Epoch_G_Loss:0.1142 ||Epoch_E_Loss:0.1102
# timer:  2.1554 sec.
# -------------
# Epoch 1477/1500
# -------------
# （train）
# -------------
# epoch 1477 || Epoch_D_Loss:0.1532 ||Epoch_G_Loss:0.0930 ||Epoch_E_Loss:0.1095
# timer:  2.5977 sec.
# -------------
# Epoch 1478/1500
# -------------
# （train）
# -------------
# epoch 1478 || Epoch_D_Loss:0.1609 ||Epoch_G_Loss:0.0958 ||Epoch_E_Loss:0.1041
# timer:  1.9844 sec.
# -------------
# Epoch 1479/1500
# -------------
# （train）
# -------------
# epoch 1479 || Epoch_D_Loss:0.1553 ||Epoch_G_Loss:0.0945 ||Epoch_E_Loss:0.1091
# timer:  1.9791 sec.
# -------------
# Epoch 1480/1500
# -------------
# （train）
# -------------
# epoch 1480 || Epoch_D_Loss:0.1324 ||Epoch_G_Loss:0.1102 ||Epoch_E_Loss:0.1244
# timer:  2.4214 sec.
# -------------
# Epoch 1481/1500
# -------------
# （train）
# -------------
# epoch 1481 || Epoch_D_Loss:0.1164 ||Epoch_G_Loss:0.1155 ||Epoch_E_Loss:0.1409
# timer:  1.8662 sec.
# -------------
# Epoch 1482/1500
# -------------
# （train）
# -------------
# epoch 1482 || Epoch_D_Loss:0.1049 ||Epoch_G_Loss:0.1456 ||Epoch_E_Loss:0.1455
# timer:  1.9590 sec.
# -------------
# Epoch 1483/1500
# -------------
# （train）
# -------------
# epoch 1483 || Epoch_D_Loss:0.0966 ||Epoch_G_Loss:0.1507 ||Epoch_E_Loss:0.1539
# timer:  2.2921 sec.
# -------------
# Epoch 1484/1500
# -------------
# （train）
# -------------
# epoch 1484 || Epoch_D_Loss:0.1021 ||Epoch_G_Loss:0.1400 ||Epoch_E_Loss:0.1525
# timer:  2.6195 sec.
# -------------
# Epoch 1485/1500
# -------------
# （train）
# -------------
# epoch 1485 || Epoch_D_Loss:0.0980 ||Epoch_G_Loss:0.1312 ||Epoch_E_Loss:0.1620
# timer:  2.5527 sec.
# -------------
# Epoch 1486/1500
# -------------
# （train）
# -------------
# epoch 1486 || Epoch_D_Loss:0.1004 ||Epoch_G_Loss:0.1370 ||Epoch_E_Loss:0.1598
# timer:  1.9543 sec.
# -------------
# Epoch 1487/1500
# -------------
# （train）
# -------------
# epoch 1487 || Epoch_D_Loss:0.0996 ||Epoch_G_Loss:0.1359 ||Epoch_E_Loss:0.1622
# timer:  2.2284 sec.
# -------------
# Epoch 1488/1500
# -------------
# （train）
# -------------
# epoch 1488 || Epoch_D_Loss:0.1047 ||Epoch_G_Loss:0.1454 ||Epoch_E_Loss:0.1520
# timer:  2.1142 sec.
# -------------
# Epoch 1489/1500
# -------------
# （train）
# -------------
# epoch 1489 || Epoch_D_Loss:0.1097 ||Epoch_G_Loss:0.1189 ||Epoch_E_Loss:0.1468
# timer:  1.6568 sec.
# -------------
# Epoch 1490/1500
# -------------
# （train）
# -------------
# epoch 1490 || Epoch_D_Loss:0.1275 ||Epoch_G_Loss:0.1195 ||Epoch_E_Loss:0.1268
# timer:  2.0325 sec.
# -------------
# Epoch 1491/1500
# -------------
# （train）
# -------------
# epoch 1491 || Epoch_D_Loss:0.1389 ||Epoch_G_Loss:0.1076 ||Epoch_E_Loss:0.1214
# timer:  2.3556 sec.
# -------------
# Epoch 1492/1500
# -------------
# （train）
# -------------
# epoch 1492 || Epoch_D_Loss:0.1374 ||Epoch_G_Loss:0.1182 ||Epoch_E_Loss:0.1176
# timer:  2.1651 sec.
# -------------
# Epoch 1493/1500
# -------------
# （train）
# -------------
# epoch 1493 || Epoch_D_Loss:0.1311 ||Epoch_G_Loss:0.1171 ||Epoch_E_Loss:0.1205
# timer:  1.9927 sec.
# -------------
# Epoch 1494/1500
# -------------
# （train）
# -------------
# epoch 1494 || Epoch_D_Loss:0.1205 ||Epoch_G_Loss:0.1277 ||Epoch_E_Loss:0.1261
# timer:  2.1691 sec.
# -------------
# Epoch 1495/1500
# -------------
# （train）
# -------------
# epoch 1495 || Epoch_D_Loss:0.1207 ||Epoch_G_Loss:0.1232 ||Epoch_E_Loss:0.1265
# timer:  2.6662 sec.
# -------------
# Epoch 1496/1500
# -------------
# （train）
# -------------
# epoch 1496 || Epoch_D_Loss:0.1204 ||Epoch_G_Loss:0.1210 ||Epoch_E_Loss:0.1271
# timer:  2.0557 sec.
# -------------
# Epoch 1497/1500
# -------------
# （train）
# -------------
# epoch 1497 || Epoch_D_Loss:0.1116 ||Epoch_G_Loss:0.1217 ||Epoch_E_Loss:0.1303
# timer:  2.1024 sec.
# -------------
# Epoch 1498/1500
# -------------
# （train）
# -------------
# epoch 1498 || Epoch_D_Loss:0.1148 ||Epoch_G_Loss:0.1284 ||Epoch_E_Loss:0.1243
# timer:  2.4151 sec.
# -------------
# Epoch 1499/1500
# -------------
# （train）
# -------------
# epoch 1499 || Epoch_D_Loss:0.1088 ||Epoch_G_Loss:0.1197 ||Epoch_E_Loss:0.1303
# timer:  1.8901 sec.
# 総イテレーション回数: 10501

# %%
# 生成画像と訓練データを可視化する
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 入力の乱数生成
batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
G_update.eval()
fake_images = G_update(fixed_z.to(device))

# 訓練データ
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す


# 出力
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

# %% [markdown]
# # テスト画像で異常検知する

# %%
# テスト用のDataLoaderの作成


def make_test_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(5):
        img_path = "./data/test_28size/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/test_28size/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/test_28size/img_2_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list


# ファイルリストを作成
test_img_list = make_test_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
test_dataset = GAN_Img_Dataset(
    file_list=test_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 5

test_dataloader = torch.utils.data.DataLoader(
    test_dataset, batch_size=batch_size, shuffle=False)

# %%
# テストデータの確認
batch_iterator = iter(test_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す

fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

# %%
def Anomaly_score(x, fake_img, z_out_real, D, Lambda=0.1):

    # テスト画像xと生成画像fake_imgのピクセルレベルの差の絶対値を求めて、ミニバッチごとに和を求める
    residual_loss = torch.abs(x-fake_img)
    residual_loss = residual_loss.view(residual_loss.size()[0], -1)
    residual_loss = torch.sum(residual_loss, dim=1)

    # テスト画像xと生成画像fake_imgを識別器Dに入力し、特徴量マップを取り出す

    _, x_feature = D(x, z_out_real)
    _, G_feature = D(fake_img, z_out_real)

    # テスト画像xと生成画像fake_imgの特徴量の差の絶対値を求めて、ミニバッチごとに和を求める
    discrimination_loss = torch.abs(x_feature-G_feature)
    discrimination_loss = discrimination_loss.view(
        discrimination_loss.size()[0], -1)
    discrimination_loss = torch.sum(discrimination_loss, dim=1)

    # ミニバッチごとに2種類の損失を足し算する
    loss_each = (1-Lambda)*residual_loss + Lambda*discrimination_loss

    # ミニバッチ全部の損失を求める
    total_loss = torch.sum(loss_each)

    return total_loss, loss_each, residual_loss

# %%
# 異常検知したい画像
x = imges[0:5]
x = x.to(device)

# 教師データの画像をエンコードしてzにしてから、Gで生成
E_update.eval()
G_update.eval()
z_out_real = E_update(imges.to(device))
imges_reconstract = G_update(z_out_real)

# 損失を求める
loss, loss_each, residual_loss_each = Anomaly_score(
    x, imges_reconstract, z_out_real, D_update, Lambda=0.1)

# 損失の計算。トータルの損失
loss_each = loss_each.cpu().detach().numpy()
print("total loss：", np.round(loss_each, 0))

# 画像を可視化
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(imges_reconstract[i][0].cpu().detach().numpy(), 'gray')
# Out:
# total loss： [149. 242. 277. 228. 243.]

# %% [markdown]
# 以上
